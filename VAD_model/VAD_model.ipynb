# %%
from pytube import YouTube
import glob
import os
import csv
import subprocess
import torch
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.nn import functional as F
from torch.autograd import Variable 
import torchvision.transforms as transforms
import pandas as pd
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import time
from torch.optim.lr_scheduler import ExponentialLR
import sklearn.metrics as metrics
from torchinfo import summary
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %% [markdown]
# # Функции, используемые в проекте

# %%
def download_audio_from_youtube(video_dataset_path: str, audio_save_dir_path: str):
    '''
    Функция загружает все аудио из спика видео c youtube в формет mp4
    Входные параметры:
    video_dataset_path: str - путь к файлу со списком видео
    audio_save_dir_path: str - путь к папке, куда сохранять аудио
    '''
    with open(video_dataset_path) as f:
        links = f.readlines()
    links = [x.replace('\n', '') for x in links]
    
    if not os.path.exists(audio_save_dir_path):
        os.makedirs(audio_save_dir_path)
        
    for link in links:
        yt=YouTube('https://www.youtube.com/watch?v=' + link)
        try:
            t=yt.streams.filter(only_audio=True)
            t[0].download(audio_save_dir_path)
            print(os.path.join(audio_save_dir_path, link + '.mp4'))
            os.rename(os.path.join(audio_save_dir_path, t[0].default_filename), 
                      os.path.join(audio_save_dir_path, link + '.mp4'))
        except:
            continue

# %%
def convert_audio_to_wav(audio_mp4_dir_path:str, audio_wav_dir_save_path:str):
    '''
    Функция конвертирует все аудио из спика из формата mp4 в формат mav с частотой 16кГц, 1 канал
    Входные параметры:
    audio_mp4_dir_path: str - путь к папке с аудио в mp4
    audio_wav_dir_save_path: str - путь к папке, куда сохранять аудио в формате wav
    '''
    if not os.path.exists(audio_wav_dir_save_path):
        os.makedirs(audio_wav_dir_save_path)
        
    for audio in glob.glob(audio_mp4_dir_path + "/*.mp4"):
        _, file = os.path.split(audio)
        command = "ffmpeg -i {} -ab 160k -ac 1 -ar 16000 -vn {}".format(audio,
                                                                           os.path.join(audio_wav_dir_save_path,
                                                                                        file.split('.')[0] + '.wav'))

        print(os.path.join(audio_wav_dir_save_path, file.split('.')[0] + '.wav'))
        subprocess.call(command, shell=True)

# %%
def dataset_to_abs_path(speech_labels_paths: str, path_to_audio_dir: str, delimiter:str = ','):
    '''
    Функция конвертирует датасет с относительными путями к датасету с абсолютными путями:
    Входные параметры:
    speech_labels_paths: str - путь к датасету с аудио
    path_to_audio_dir: str - путь к папке с аудио wav
    delimiter:str = ',' - разделитель в датасете
    '''
    with open(speech_labels_paths) as f:
        speech_labels = f.readlines()
        
    speech_labels = [path_to_audio_dir + '/' + x.split(delimiter)[0] + '.wav,' + delimiter.join(x.split(delimiter)[1:]) for x in speech_labels]
    with open(speech_labels_paths, 'w') as f:
        f.writelines(speech_labels)

# %%
def create_spec_dataset(speech_labels_paths: str, path_specs: str, delimiter: str=','):
    '''
    Функция принимает на вход пути ко всем аудио датасета и преобразует их к спектрограммам
    Входные данные:
    speech_labels_paths: str - путь к датасету AVA формата
    path_specs: str - путь к папке, куда сохранять спектрограммы
    delimeter: str=',' - разделитель в датасете
    '''
    with open(speech_labels_paths) as f:
        speech_labels = f.readlines()
    speech_labels = [x.replace('\n', '') for x in speech_labels]
    
    if not os.path.exists(path_specs):
        os.makedirs(path_specs)
    
    i = 0
    labels = []
    sample_rate = 16000
    win_length = hop_length = n_fft = int(sample_rate/100)
    step = int(0.32*sample_rate)
    while i < len(speech_labels):
        path_to_audio = speech_labels[i].split(delimiter)[0]
        audio = path_to_audio.split('/')[-1].split('.')[0]
        try:
            waveform, _ = torchaudio.load(path_to_audio)
            print(path_to_audio)
        except:
            i += 1
            continue
        j = 0
        while True:
            speech_label_split = speech_labels[i].split(delimiter)
            second_start = float(speech_label_split[1])
            second_end = float(speech_label_split[2])
            label = speech_label_split[3]
            if label == 'NO_SPEECH':
                label = '0'
            else:
                label = '1'
            while (second_start*sample_rate < waveform.shape[1] - step) and (second_end - second_start > 0.32):
                specgram = torchaudio.transforms.MelSpectrogram(sample_rate = sample_rate, win_length=win_length, 
                                                                n_mels=32, power=1, hop_length=hop_length, n_fft=n_fft+1)(waveform[0][int(second_start*sample_rate):int(second_start*sample_rate) + step])
                data = specgram.log2().detach().numpy()
                if True in np.isinf(data):
                    j += 1
                    second_start += 0.32
                    continue
                np.save(path_specs + '/{0}_{1}'.format(audio, str(j)), data)
                labels.append([path_specs + '/{0}_{1}.npy'.format(audio, str(j)), label])
                j += 1
                second_start += 0.32
            i += 1
            if speech_labels[i].split(delimiter)[0] != path_to_audio:
                break
    return np.array(labels)

# %%
def create_train_test_dataset(data: str, test_size: float=0.2):
    '''
    Функция принимает на вход файл с указанием путей ко всем спектрограммам и их меткам
    Входные данные:
    data: str - список путей к спектрограммам и их меток
    test_size: float=0.2 - доля тестовой выборки в общем количестве данных
    '''
    np.random.shuffle(data)
    df = pd.DataFrame(data)
    df = df.rename(columns={0: 'spec_paths', 1: 'labels'})
    m = df.loc[:, 'labels'] == '0'
    df.loc[m, 'labels'] = 0
    m = df.loc[:, 'labels'] != 0
    df.loc[m, 'labels'] = 1
    test_df = df.loc[:int(df.shape[0]*test_size)].reset_index()
    train_df = df.loc[int(df.shape[0]*test_size):].reset_index().drop('index', axis=1)
    return train_df, test_df

# %%
def visualize_spec(df: pd.DataFrame, idx: int):
    '''
    Функция принимает на вход датасет и индекс и визуализирует соответствующую спектрограмму
    Входные данные:
    df: pd.DataFrame - датафрейм с данными
    idx: int - индекс визуализируемого элемента
    '''
    im = np.load(df.iloc[idx, 0])
    plt.imshow(im, cmap='jet')
    plt.show()
    print(df.iloc[i, 1])

# %%
def get_mean_std(research_data_loader: DataLoader):
    '''
    Функция принимает на вход исследуемый датасет и вычисляет по нему среднее и СКО
    Входные данные:
    research_data_loader: DataLoader - датасет, приведенный к формату DataLoader
    '''
    nimages = 0
    mean = 0.
    std = 0.
    for batch in research_data_loader:
        nimages += 1
        mean += batch[0].mean()
        std += batch[0].std()

    mean /= nimages
    std /= nimages
    return float(mean), float(std)

# %%
def test_result(model, test_data_loader: DataLoader):
    '''
    Функция принимает на вход модель и тестовый датасет и вычисляет по нему значение метрики и предсказанные 
    значения
    Входные данные:
    model - обученная модель
    test_data_loader: DataLoader - тестовый датасет, приведенный к формату DataLoader
    '''
    model.eval()
    test_metrics = []
    test_losses = []
    result = {}
    y_true = []
    y_proba = []
    for batch_idx, data in enumerate(test_data_loader):
        inputs = data[0]
        target = data[1]
        outputs = model(inputs)        
        loss = criterion(outputs[:, 0], target.to(torch.float32))
        test_losses.append(loss.item())
        y_true.append(np.array(target.detach().numpy()))
        y_proba.append(np.array(outputs[:,0].detach().numpy()))

    y_true = np.concatenate(np.array(y_true), axis=0)
    y_proba = np.concatenate(np.array(y_proba), axis=0)

    test_loss    = np.mean(test_losses)
    test_metric  = metric(y_true, y_proba)
    result['test_loss'] = test_loss
    result['test_metric'] = test_metric
    print(result)
    return y_true, y_proba

# %%
def show_proba_calibration_plots(y_predicted_probs, y_true_labels):
    '''
    Функция принимает на вход предсказзные моделью значения и истинные метки и строит изменения f1, precision, 
    recall при изменяющемся значении порога от 0.1 до 0.9
    Входные данные:
    y_predicted_probs - предсказанные моделью значения
    y_true_labels - истинные значения
    '''
    preds_with_true_labels = np.array(list(zip(y_predicted_probs, y_true_labels)))

    thresholds = []
    precisions = []
    recalls = []
    f1_scores = []

    for threshold in np.linspace(0.1, 0.9, 9):
        thresholds.append(threshold)
        precisions.append(precision_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        recalls.append(recall_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        f1_scores.append(f1_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))

    scores_table = pd.DataFrame({'f1':f1_scores,
                                 'precision':precisions,
                                 'recall':recalls,
                                 'probability':thresholds}).sort_values('f1', ascending=False).round(3)
  
    figure = plt.figure(figsize = (15, 5))

    plt1 = figure.add_subplot(121)
    plt1.plot(thresholds, precisions, label='Precision', linewidth=4)
    plt1.plot(thresholds, recalls, label='Recall', linewidth=4)
    plt1.plot(thresholds, f1_scores, label='F1', linewidth=4)
    plt1.set_ylabel('Scores')
    plt1.set_xlabel('Probability threshold')
    plt1.set_title('Probabilities threshold calibration')
    plt1.legend(bbox_to_anchor=(0.25, 0.25))   
    plt1.table(cellText = scores_table.values,
               colLabels = scores_table.columns, 
               colLoc = 'center', cellLoc = 'center', loc = 'bottom', bbox = [0, -1.3, 1, 1])

    plt2 = figure.add_subplot(122)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 0][:, 0], 
              label='Сlass 0', color='royalblue', alpha=1)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 1][:, 0], 
              label='Class 1', color='darkcyan', alpha=0.8)
    plt2.set_ylabel('Number of examples')
    plt2.set_xlabel('Probabilities')
    plt2.set_title('Probability histogram')
    plt2.legend(bbox_to_anchor=(1, 1))

    plt.show()

# %%
def labels_pred(pred_proba, threshold):
    '''
    Функция принимает на вход предсказзные моделью значения и значение порога и преобразует значения
    к бинарной классификации
    Входные данные:
    pred_proba - предсказанные моделью значения
    threshold - пороговое значение
    '''
    _labels_pred = np.array(list(map(lambda x: 0 if x<threshold else 1, pred_proba)))
    return _labels_pred

# %%
def report(y_true, y_prob, threshold=0.4):
    '''
    Функция принимает на вход предсказзные моделью значения, истинные значения и значение порога
    и получает матрицу ошибок для заданного порога
    Входные данные:
    y_true - истинные значения
    y_prob - предсказанные моделью значения
    threshold=0.4 - пороговое значение
    '''
    tn, fp, fn, tp = confusion_matrix(y_true, labels_pred(y_prob, threshold)).ravel()
    print(classification_report(y_true, labels_pred(y_prob, threshold)))
    print('---------------')
    print('Матрица ошибок:')
    print(confusion_matrix(y_true, labels_pred(y_prob, threshold)))
    print('---------------')
    print(f'Правильно предсказано 0: {tn}')
    print(f'Правильно предсказано 1: {tp}')
    print(f'Ложноотрицательных (FN, ош2р, пропуск события): {fn}')
    print(f'Ложноположительных (FP, ош1р, ложная  тревога): {fp}')
    print(f'Всего ошибок: {fp+fn}')

# %%
def plot_precision_recall(y_true, y_proba):
    '''
    Функция принимает на вход предсказаные моделью значения и истинные значения и строит PR кривую с f1 изолиниями
    Входные данные:
    y_true - истинные значения
    y_prob - предсказанные моделью значения
    '''
    _, ax = plt.subplots(figsize=(7, 7))

    prec, recall, _ = precision_recall_curve(y_true, y_proba)
    ax.plot(recall, prec, linewidth=2, color='r')

    f_scores = np.linspace(0.2, 0.8, num=4)
    for f_score in f_scores:
        x = np.linspace(0.01, 1)
        y = f_score * x / (2 * x - f_score)
        ax.plot(x[y >= 0], y[y >= 0], color="gray", alpha=0.5)

    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([min(prec), 1.01])
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.grid()

# %%
def plot_PR_ROC(y_true, y_proba):
    '''
    Функция принимает на вход предсказаные моделью значения и истинные значения и строит PR и ROC кривые
    Входные данные:
    y_true - истинные значения
    y_prob - предсказанные моделью значения
    '''
    figure = plt.figure(figsize = (16, 7))
    plt1 = figure.add_subplot(121)

    prec, recall, _ = precision_recall_curve(y_true, y_proba)
    plt1.plot(recall, prec, linewidth=2, color='r')

    f_scores = np.linspace(0.2, 0.8, num=4)
    for f_score in f_scores:
        x = np.linspace(0.01, 1)
        y = f_score * x / (2 * x - f_score)
        plt1.plot(x[y >= 0], y[y >= 0], color="gray", alpha=0.5)

    plt1.set_xlim([0.0, 1.0])
    plt1.set_ylim([min(prec), 1.01])
    plt1.set_xlabel('Recall')
    plt1.set_ylabel('Precision')
    plt1.grid()

    plt2 = figure.add_subplot(122)
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    roc_auc = roc_auc_score(y_true, y_proba)
    plt2.set_xlim([0.0, 1.0])
    plt2.set_ylim([0.0, 1.0])
    plt2.plot(fpr, tpr)
    plt2.set_xlabel('False positive rate')
    plt2.set_ylabel('True positive rate')
    plt2.set_title(f'ROC curve. ROC_AUC = {roc_auc:.3f}')
    plt2.grid()

# %% [markdown]
# # Классы, используемые в проекте

# %%
class AVADataset(Dataset):
    '''
    Конструктор класса принимает датафрейм с путями к спектрограммам, среднее и СКО, вычисленные по
    исследовательским данным.
    Возвращает стандратизованную спектрограмму формы (1, 32, 32) и метку ее класса
    '''
    def __init__(self, dataframe: pd.DataFrame, mean: float, std: float):
        self.spec_paths = dataframe['spec_paths']
        self.labels = dataframe['labels']
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return ((np.load(self.spec_paths[idx])-self.mean)/self.std).reshape(-1,32,32), self.labels[idx]

# %%
class ModelVad(nn.Module):
    '''
    Класс, описывающий модель VAD
    '''
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5, stride=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 128, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(6*6*128, 64)
        self.bilstm = nn.LSTM(1, hidden_size=128, bidirectional=True, batch_first = True)
        self.fc2 = nn.Linear(256, 2)
        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(128)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1,6*6*128)
        x = F.relu(self.fc1(x))
        x = x.view(-1,64,1)
        x, (h, c) = self.bilstm(x)
        x = torch.cat((h[0,:,:], h[1,:,:]), 1)
        x = x.view(-1,256)
        x = self.fc2(x)
        x = F.softmax(x, -1)
        return x

# %%
class ModelWrapper(nn.Module):
    '''
    Класс для работы с моделью
    '''
    def __init__(self, model: object):
        super(ModelWrapper, self).__init__()
        self.model = model

        
    def forward(self, input_data):
        output_data = self.model(input_data)
        return output_data
    
    
    def fit(self, criterion: object, metric: object, optimizer: object, scheduler: object,
                  train_data_loader: DataLoader, valid_data_loader: DataLoader=None, 
                  epochs: int=1, verbose: int=5):        
        '''Метод для обучения модели
        Входные параметры:
        criterion: object - объект для вычисления loss
        metric: object - объект для вычисления метрики качества
        optimizer: object - оптимизатор
        scheduler: object - объект для изменения lr в ходе обучения
        train_data_loader: DataLoader - загрузчик данных для обучения
        valid_data_loader: DataLoader - загрузчик данных для валидации
        epochs: int - количество эпох обучения
        verbose: int - вывод информации через каждые verbose итераций
        Возвращаемые значения:
        result: dict - словарь со значениями loss при тренировке, валидации и метрики при валидации 
        для каждой эпохи'''
        self.optimizer = optimizer
        epoch_train_losses = []
        epoch_valid_losses = []
        epoch_valid_metrics = []
        result = {}
        
        for epoch in range(epochs):
            self.model.train()
            time1 = time.time()
            running_loss = 0.0
            train_losses = []
            
            for batch_idx, data in enumerate(train_data_loader):

                inputs, target = data[0], data[1]
                optimizer.zero_grad()
                outputs = self.model(inputs)

                loss = criterion(outputs[:,0], target.to(torch.float32))
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                train_losses.append(loss.item())
                if (batch_idx+1) % verbose == 0:
                    print(f'Train Epoch: {epoch+1}, Loss: {(running_loss/verbose):.6f}, ', end="")
                    print(f'Learning rate: {scheduler.get_last_lr()[0]}')
                    time2 = time.time()
                    print(f'Spended time for {verbose} batches (total: {batch_idx})({int((verbose*data[0].shape[0]))} images', end="") 
                    print(f': {(time2-time1):.6f} sec')
                    
                    time1 = time.time()
                    running_loss = 0.0
                if (batch_idx+1) % 3000 == 0:
                    train_loss = np.mean(train_losses)
                    if valid_data_loader != None:
                        valid_result = self.valid(criterion, metric, valid_data_loader)
                        valid_loss = valid_result['valid_loss']
                        valid_metric = valid_result['valid_metric']

                        print('='*80)
                        print(f'Epoch {epoch+1}, train loss: {(train_loss):.6f}, valid loss: {(valid_loss):.6f}, ', end="")
                        print(f'valid metric: {(valid_metric):.6f}')
                        print('='*80)
                    else:
                        print('='*80)
                        print(f'Epoch {epoch+1}, train loss: {(train_loss):.6f}')
                        print('='*80)
                        valid_loss = None
                        valid_metric = None

            train_loss = np.mean(train_losses)
            scheduler.step()
            
            if valid_data_loader != None:
                valid_result = self.valid(criterion, metric, valid_data_loader)
                valid_loss = valid_result['valid_loss']
                valid_metric = valid_result['valid_metric']

                print('='*80)
                print(f'Epoch {epoch+1}, train loss: {(train_loss):.6f}, valid loss: {(valid_loss):.6f}, ', end="")
                print(f'valid metric: {(valid_metric):.6f}')
                print('='*80)
            else:
                print('='*80)
                print(f'Epoch {epoch+1}, train loss: {(train_loss):.6f}')
                print('='*80)
                valid_loss = None
                valid_metric = None
            epoch_train_losses.append(train_loss)
            epoch_valid_losses.append(valid_loss)
            epoch_valid_metrics.append(valid_metric)
        
        result['epoch_train_losses'] = epoch_train_losses
        result['epoch_valid_losses'] = epoch_valid_losses
        result['epoch_valid_metrics'] = epoch_valid_metrics
        
        return result
    
    
    def valid(self, criterion: object, metric: object, valid_data_loader: DataLoader):
        '''Метод для валидации модели
        Входные параметры:
        criterion: object - объект для вычисления loss
        metric: object - объект для вычисления метрики качества
        valid_data_loader: DataLoader - загрузчик данных для валидации
        Возвращаемые значения:
        result: dict - словарь со значениями loss и метрики при валидации'''
        self.model.eval()
        valid_metrics = []
        valid_losses = []
        result = {}
        y_true = []
        y_proba = []
        for batch_idx, data in enumerate(valid_data_loader):
            inputs = data[0]
            target = data[1]
            outputs = self.model(inputs)        
            loss = criterion(outputs[:, 0], target.to(torch.float32))
            valid_losses.append(loss.item())
            y_true.append(np.array(target.detach().numpy()))
            y_proba.append(np.array(outputs[:,0].detach().numpy()))
        y_true = np.concatenate(np.array(y_true), axis=0)
        y_proba = np.concatenate(np.array(y_proba), axis=0)
        valid_loss    = np.mean(valid_losses)
        valid_metric  = metric(y_true, y_proba)
        result['valid_loss'] = valid_loss
        result['valid_metric'] = valid_metric
        self.model.train()
        return result
    
    
    def save(self, path_to_save: str = './VAD_model.pth'):
        torch.save(self.model.state_dict(), path_to_save)


    def load(self, path_to_model: str = './VAD_model.pth'):
        self.model.load_state_dict(torch.load(path_to_model))

# %% [markdown]
# # Пайплайн данных

# %% [markdown]
# ### Загрузка аудио

# %%
download_audio_from_youtube('/Users/igorfrolkin/Downloads/ava_video_list_v1.0.txt','/Users/igorfrolkin/Downloads/ava_sounds_2')
# Out:
# /Users/igorfrolkin/Downloads/ava_sounds_2/053oq2xB3oU.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/2bxKkUgcqpk.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/2fwni_Kjf2M.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/2PpxiG0WU18.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/2qQs3Y9OJX0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/2XeFK-DTSZk.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/32HR3MnDZ8g.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/4gVsDd8PV9U.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/4ZpjKfu6Cl8.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/55Ihr6uVIDA.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/5BDj0ow5hnA.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/-5KQ66BBWC4.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/5milLu-6bWI.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/5YPjcdLbs5g.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/6d5u6FHvz7Q.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/7nHkh4sP5Ks.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/7YpF6DntOYw.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/8aMv-ZGD4ic.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/8nO5FFbIAog.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/914yZXz-iRs.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/9bK05eBt1GM.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/9F2voT6QWvQ.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/9mLYmkonWZQ.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/9Y_l9NsnYE0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/a5mEmM6w_ks.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/_a9SWtcaNj8.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Ag-pXiLrd48.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/AN07xQokfiE.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/ax3q-RkVIt4.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/b5pRYl_djbs.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/BCiuXAuCKAU.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/bhlFavrh7WU.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/BY3sZmvUp-0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/cKA-qeZuH_w.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/CrlfWnsS7ac.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/CZ2NP8UsPuE.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Db19rWN5BGo.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Di1MG6auDYo.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/E7JcKooKVsM.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Ekwy7wzLfjc.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/F3dPH6Xqf5M.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/fD6VkIRlIRI.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/fNcxxBjEOgw.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/g1wyIcLPbq0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/G5Yr20A5z_Q.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/gjdgj04FzR0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/hHgg9WI8dTk.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Hi8QeP_VPu0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/HKjR70GCRPE.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/-IELREHX_js.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/IKdBLciu_-A.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/IzvOYVMltkI.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/J4bt4y9ShTA.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/jgAwJ0RqmYg.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/JNb4nWexD0I.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Kb1fduj-jdY.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/kMy-6RtoOVU.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/K_SpqDJnlps.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/KWoSGtglCms.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/LgBQlW6OTr0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/l-jxh8gpxuY.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/lWXhqIAvarw.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/_mAfwH6i90E.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/N1K2bEZLL_A.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/N5UD8FGzDek.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/oD_wxyTHJ2I.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/OfMdakd4bHI.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/O_NYCUhZ9zw.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/oq_bufAhyl8.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/Ov0za6Xb1LM.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/phrYEKv0rmw.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/phVLLTMzmKk.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/plkJ45_-pMk.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/PNZQ2UJfyQE.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/QCLQYnt3aMo.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/QMwT7DFA5O4.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/qrkff49p4E4.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/qx2vAO5ofmo.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/rFgb2ECMcrY.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/rk8Xm0EAOWs.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/rUYsoIIE37A.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/skiZueh4lfY.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/tghXjom3120.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/tNpZtigMc4g.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/tt0t_a1EDCE.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/u1ltv6r14KQ.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/U6m3kNFjdTs.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/UgZFdrNT6W0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/uzPI7FcF79U.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/vfjywN5CN0Y.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/VsYPP2I0aUQ.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/WwoTG3_OjUg.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/xmqSaQPzL1E.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/xO4ABy2iOQA.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/y7ncweROe9U.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/yMtGmGa8KZ0.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/yo-Kg2YxlZs.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/z-fsLpGHq6o.mp4
# /Users/igorfrolkin/Downloads/ava_sounds_2/zR725veL-DI.mp4

# %%
convert_audio_to_wav('/Users/igorfrolkin/Downloads/ava_sounds_2', '/Users/igorfrolkin/Downloads/ava_sounds_2/wav')
# Out:
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/7nHkh4sP5Ks.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9Y_l9NsnYE0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/U6m3kNFjdTs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/4gVsDd8PV9U.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/cKA-qeZuH_w.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/N1K2bEZLL_A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/HKjR70GCRPE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/plkJ45_-pMk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/-IELREHX_js.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tt0t_a1EDCE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/skiZueh4lfY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/fD6VkIRlIRI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/IzvOYVMltkI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tNpZtigMc4g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/4ZpjKfu6Cl8.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/J4bt4y9ShTA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/UgZFdrNT6W0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/BCiuXAuCKAU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/a5mEmM6w_ks.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/KWoSGtglCms.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/lWXhqIAvarw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/oD_wxyTHJ2I.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2XeFK-DTSZk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/7YpF6DntOYw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5milLu-6bWI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rFgb2ECMcrY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/CZ2NP8UsPuE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/phrYEKv0rmw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Db19rWN5BGo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5YPjcdLbs5g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/_mAfwH6i90E.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/WwoTG3_OjUg.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/K_SpqDJnlps.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/gjdgj04FzR0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/g1wyIcLPbq0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/6d5u6FHvz7Q.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/-5KQ66BBWC4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2fwni_Kjf2M.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2qQs3Y9OJX0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/E7JcKooKVsM.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/914yZXz-iRs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/053oq2xB3oU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/O_NYCUhZ9zw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/bhlFavrh7WU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/32HR3MnDZ8g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/u1ltv6r14KQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/qx2vAO5ofmo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/8nO5FFbIAog.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/b5pRYl_djbs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/PNZQ2UJfyQE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/vfjywN5CN0Y.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Hi8QeP_VPu0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/uzPI7FcF79U.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/F3dPH6Xqf5M.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5BDj0ow5hnA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/G5Yr20A5z_Q.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/IKdBLciu_-A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/CrlfWnsS7ac.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/ax3q-RkVIt4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9mLYmkonWZQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2PpxiG0WU18.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9F2voT6QWvQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/QMwT7DFA5O4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/phVLLTMzmKk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/BY3sZmvUp-0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/JNb4nWexD0I.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rk8Xm0EAOWs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9bK05eBt1GM.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Ag-pXiLrd48.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/l-jxh8gpxuY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/yo-Kg2YxlZs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/AN07xQokfiE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/kMy-6RtoOVU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/hHgg9WI8dTk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2bxKkUgcqpk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/OfMdakd4bHI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/_a9SWtcaNj8.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/N5UD8FGzDek.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/yMtGmGa8KZ0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/xO4ABy2iOQA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rUYsoIIE37A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/xmqSaQPzL1E.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tghXjom3120.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Ov0za6Xb1LM.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/qrkff49p4E4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/zR725veL-DI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/VsYPP2I0aUQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/y7ncweROe9U.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/QCLQYnt3aMo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/55Ihr6uVIDA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/jgAwJ0RqmYg.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/8aMv-ZGD4ic.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/z-fsLpGHq6o.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/LgBQlW6OTr0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/oq_bufAhyl8.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/fNcxxBjEOgw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Kb1fduj-jdY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Di1MG6auDYo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Ekwy7wzLfjc.wav

# %%
dataset_to_abs_path('/Users/igorfrolkin/Downloads/ava_speech_labels_v1.csv', '/Users/igorfrolkin/Downloads/ava_sounds_2/wav')

# %% [markdown]
# ### Подготовка спектрограмм

# %%
labels = create_spec_dataset('/Users/igorfrolkin/Downloads/ava_speech_labels_v1.csv',
                    '/Users/igorfrolkin/Downloads/ava_spec_2', ',')
# Out:
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5BDj0ow5hnA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/JNb4nWexD0I.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/plkJ45_-pMk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/oD_wxyTHJ2I.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5YPjcdLbs5g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/BCiuXAuCKAU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/UgZFdrNT6W0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rk8Xm0EAOWs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rUYsoIIE37A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/HKjR70GCRPE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/PNZQ2UJfyQE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/_mAfwH6i90E.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/IKdBLciu_-A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/914yZXz-iRs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/J4bt4y9ShTA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/7YpF6DntOYw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2fwni_Kjf2M.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/-5KQ66BBWC4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/kMy-6RtoOVU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/5milLu-6bWI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9F2voT6QWvQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/WwoTG3_OjUg.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2XeFK-DTSZk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2PpxiG0WU18.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9mLYmkonWZQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/32HR3MnDZ8g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2qQs3Y9OJX0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/yo-Kg2YxlZs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/BY3sZmvUp-0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/skiZueh4lfY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/6d5u6FHvz7Q.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/K_SpqDJnlps.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Hi8QeP_VPu0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/OfMdakd4bHI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/AN07xQokfiE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/N1K2bEZLL_A.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/vfjywN5CN0Y.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/a5mEmM6w_ks.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/-IELREHX_js.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tNpZtigMc4g.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/U6m3kNFjdTs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/QMwT7DFA5O4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/N5UD8FGzDek.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/phVLLTMzmKk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9Y_l9NsnYE0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/l-jxh8gpxuY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/4ZpjKfu6Cl8.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/7nHkh4sP5Ks.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/ax3q-RkVIt4.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/uzPI7FcF79U.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/IzvOYVMltkI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tt0t_a1EDCE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/tghXjom3120.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/phrYEKv0rmw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/lWXhqIAvarw.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/cKA-qeZuH_w.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/g1wyIcLPbq0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/xO4ABy2iOQA.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/F3dPH6Xqf5M.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/rFgb2ECMcrY.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/E7JcKooKVsM.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/yMtGmGa8KZ0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/4gVsDd8PV9U.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/b5pRYl_djbs.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/bhlFavrh7WU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/qx2vAO5ofmo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/gjdgj04FzR0.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/8nO5FFbIAog.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/_a9SWtcaNj8.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/KWoSGtglCms.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/u1ltv6r14KQ.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/G5Yr20A5z_Q.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/2bxKkUgcqpk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/053oq2xB3oU.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/CZ2NP8UsPuE.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/CrlfWnsS7ac.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Ag-pXiLrd48.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/fD6VkIRlIRI.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/xmqSaQPzL1E.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/9bK05eBt1GM.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/hHgg9WI8dTk.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/Db19rWN5BGo.wav
# /Users/igorfrolkin/Downloads/ava_sounds_2/wav/O_NYCUhZ9zw.wav

# %%
np.save('/Users/igorfrolkin/Downloads/labels_2', labels)

# %% [markdown]
# ### Подготовка датасетов для обучения и тестов

# %%
train_df, test_df = create_train_test_dataset(labels)
train_df.head()
# Out:
#                                           spec_paths labels
# 0  /Users/igorfrolkin/Downloads/ava_spec_2/Ag-pXi...      1
# 1  /Users/igorfrolkin/Downloads/ava_spec_2/N1K2bE...      1
# 2  /Users/igorfrolkin/Downloads/ava_spec_2/plkJ45...      1
# 3  /Users/igorfrolkin/Downloads/ava_spec_2/2bxKkU...      0
# 4  /Users/igorfrolkin/Downloads/ava_spec_2/qx2vAO...      0

# %%
print(f'Images for train: {train_df.shape[0]}, images for test: {test_df.shape[0]}')
# Out:
# Images for train: 176934, images for test: 44234

# %%
for i in range(100,110):
    visualize_spec(train_df, i)
# Out:
# 1
# 1
# 0
# 1
# 1
# 0
# 0
# 1
# 0
# 0

# %% [markdown]
# ### Вычисление параметров стандартизации данных

# %%
research_dataset = AVADataset(train_df, 0, 1)
research_data_loader = DataLoader(research_dataset, batch_size=32, shuffle=True, num_workers=2)

# %%
mean, std = get_mean_std(research_data_loader)

# %%
mean, std
# Out:
# (-3.052366018295288, 2.4621522426605225)

# %% [markdown]
# ### Создание dataloaders для всех датасетов

# %%
train_df, valid_df = train_test_split(train_df, test_size=0.1, random_state=42)
train_df.reset_index(drop=True, inplace=True)
valid_df.reset_index(drop=True, inplace=True)

#mean=-3.052366018295288
#std=2.4621522426605225
train_dataset = AVADataset(train_df, mean, std)
valid_dataset = AVADataset(valid_df, mean, std)
test_dataset = AVADataset(test_df, mean, std)

train_data_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
valid_data_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True, num_workers=2)
test_data_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=2)

print(f'Images for train: {train_df.shape[0]}, images for validation: {valid_df.shape[0]}, images for test: {test_df.shape[0]}')
# Out:
# Images for train: 159240, images for validation: 17694, images for test: 44234

# %% [markdown]
# ### Создание модели

# %%
model = ModelVad()
model_wrapper = ModelWrapper(model=model)
summary(model_wrapper.model, input_size=(32, 1, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ModelVad                                 --                        --
# ├─Conv2d: 1-1                            [32, 32, 28, 28]          832
# ├─MaxPool2d: 1-2                         [32, 32, 14, 14]          --
# ├─Conv2d: 1-3                            [32, 128, 12, 12]         36,992
# ├─MaxPool2d: 1-4                         [32, 128, 6, 6]           --
# ├─Linear: 1-5                            [32, 64]                  294,976
# ├─LSTM: 1-6                              [32, 64, 256]             134,144
# ├─Linear: 1-7                            [32, 2]                   514
# ==========================================================================================
# Total params: 467,458
# Trainable params: 467,458
# Non-trainable params: 0
# Total mult-adds (M): 475.51
# ==========================================================================================
# Input size (MB): 0.13
# Forward/backward pass size (MB): 15.35
# Params size (MB): 1.87
# Estimated Total Size (MB): 17.35
# ==========================================================================================

# %%
learning_rate = 0.005
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) 
scheduler = ExponentialLR(optimizer, gamma=0.95)
metric = metrics.roc_auc_score
criterion = torch.nn.BCELoss()

# %% [markdown]
# ### Обучение

# %%
result_train = model_wrapper.fit(criterion,
             metric,
             optimizer,
             scheduler,
             train_data_loader,
             valid_data_loader,
             epochs=10,
             verbose=10)
# Out:
# Train Epoch: 1, Loss: 0.694981, Learning rate: 0.005
# Spended time for 10 batches (total: 9)(320 images: 1.859464 sec
# Train Epoch: 1, Loss: 0.647794, Learning rate: 0.005
# Spended time for 10 batches (total: 19)(320 images: 1.673875 sec
# Train Epoch: 1, Loss: 0.650190, Learning rate: 0.005
# Spended time for 10 batches (total: 29)(320 images: 1.701295 sec
# Train Epoch: 1, Loss: 0.654098, Learning rate: 0.005
# Spended time for 10 batches (total: 39)(320 images: 1.619082 sec
# Train Epoch: 1, Loss: 0.636588, Learning rate: 0.005
# Spended time for 10 batches (total: 49)(320 images: 1.581786 sec
# Train Epoch: 1, Loss: 0.642750, Learning rate: 0.005
# Spended time for 10 batches (total: 59)(320 images: 1.577924 sec
# Train Epoch: 1, Loss: 0.595287, Learning rate: 0.005
# Spended time for 10 batches (total: 69)(320 images: 1.576453 sec
# Train Epoch: 1, Loss: 0.597788, Learning rate: 0.005
# Spended time for 10 batches (total: 79)(320 images: 1.586116 sec
# Train Epoch: 1, Loss: 0.559825, Learning rate: 0.005
# Spended time for 10 batches (total: 89)(320 images: 1.594716 sec
# Train Epoch: 1, Loss: 0.554496, Learning rate: 0.005
# Spended time for 10 batches (total: 99)(320 images: 1.578603 sec
# Train Epoch: 1, Loss: 0.557238, Learning rate: 0.005
# Spended time for 10 batches (total: 109)(320 images: 1.581915 sec
# Train Epoch: 1, Loss: 0.478676, Learning rate: 0.005
# Spended time for 10 batches (total: 119)(320 images: 1.571809 sec
# Train Epoch: 1, Loss: 0.564109, Learning rate: 0.005
# Spended time for 10 batches (total: 129)(320 images: 1.569827 sec
# Train Epoch: 1, Loss: 0.552904, Learning rate: 0.005
# Spended time for 10 batches (total: 139)(320 images: 1.574647 sec
# Train Epoch: 1, Loss: 0.540478, Learning rate: 0.005
# Spended time for 10 batches (total: 149)(320 images: 1.575926 sec
# Train Epoch: 1, Loss: 0.495905, Learning rate: 0.005
# Spended time for 10 batches (total: 159)(320 images: 1.583956 sec
# Train Epoch: 1, Loss: 0.501948, Learning rate: 0.005
# Spended time for 10 batches (total: 169)(320 images: 1.576854 sec
# Train Epoch: 1, Loss: 0.486567, Learning rate: 0.005
# Spended time for 10 batches (total: 179)(320 images: 1.583952 sec
# Train Epoch: 1, Loss: 0.454392, Learning rate: 0.005
# Spended time for 10 batches (total: 189)(320 images: 1.580171 sec
# Train Epoch: 1, Loss: 0.502348, Learning rate: 0.005
# Spended time for 10 batches (total: 199)(320 images: 1.665661 sec
# Train Epoch: 1, Loss: 0.496185, Learning rate: 0.005
# Spended time for 10 batches (total: 209)(320 images: 2.660956 sec
# Train Epoch: 1, Loss: 0.524578, Learning rate: 0.005
# Spended time for 10 batches (total: 219)(320 images: 2.728627 sec
# Train Epoch: 1, Loss: 0.441690, Learning rate: 0.005
# Spended time for 10 batches (total: 229)(320 images: 1.944226 sec
# Train Epoch: 1, Loss: 0.549411, Learning rate: 0.005
# Spended time for 10 batches (total: 239)(320 images: 1.687700 sec
# Train Epoch: 1, Loss: 0.492841, Learning rate: 0.005
# Spended time for 10 batches (total: 249)(320 images: 1.704379 sec
# Train Epoch: 1, Loss: 0.466800, Learning rate: 0.005
# Spended time for 10 batches (total: 259)(320 images: 1.820851 sec
# Train Epoch: 1, Loss: 0.522670, Learning rate: 0.005
# Spended time for 10 batches (total: 269)(320 images: 1.888071 sec
# Train Epoch: 1, Loss: 0.495835, Learning rate: 0.005
# Spended time for 10 batches (total: 279)(320 images: 1.668997 sec
# Train Epoch: 1, Loss: 0.456001, Learning rate: 0.005
# Spended time for 10 batches (total: 289)(320 images: 1.697986 sec
# Train Epoch: 1, Loss: 0.434268, Learning rate: 0.005
# Spended time for 10 batches (total: 299)(320 images: 1.698510 sec
# Train Epoch: 1, Loss: 0.433077, Learning rate: 0.005
# Spended time for 10 batches (total: 309)(320 images: 1.723246 sec
# Train Epoch: 1, Loss: 0.454232, Learning rate: 0.005
# Spended time for 10 batches (total: 319)(320 images: 1.797355 sec
# Train Epoch: 1, Loss: 0.541008, Learning rate: 0.005
# Spended time for 10 batches (total: 329)(320 images: 1.795925 sec
# Train Epoch: 1, Loss: 0.490402, Learning rate: 0.005
# Spended time for 10 batches (total: 339)(320 images: 1.686098 sec
# Train Epoch: 1, Loss: 0.488292, Learning rate: 0.005
# Spended time for 10 batches (total: 349)(320 images: 1.699265 sec
# Train Epoch: 1, Loss: 0.455130, Learning rate: 0.005
# Spended time for 10 batches (total: 359)(320 images: 1.740067 sec
# Train Epoch: 1, Loss: 0.534225, Learning rate: 0.005
# Spended time for 10 batches (total: 369)(320 images: 2.303139 sec
# Train Epoch: 1, Loss: 0.418931, Learning rate: 0.005
# Spended time for 10 batches (total: 379)(320 images: 1.887155 sec
# Train Epoch: 1, Loss: 0.468576, Learning rate: 0.005
# Spended time for 10 batches (total: 389)(320 images: 1.616111 sec
# Train Epoch: 1, Loss: 0.375901, Learning rate: 0.005
# Spended time for 10 batches (total: 399)(320 images: 1.590622 sec
# Train Epoch: 1, Loss: 0.493877, Learning rate: 0.005
# Spended time for 10 batches (total: 409)(320 images: 1.595365 sec
# Train Epoch: 1, Loss: 0.435741, Learning rate: 0.005
# Spended time for 10 batches (total: 419)(320 images: 1.597804 sec
# Train Epoch: 1, Loss: 0.424895, Learning rate: 0.005
# Spended time for 10 batches (total: 429)(320 images: 2.589137 sec
# Train Epoch: 1, Loss: 0.483597, Learning rate: 0.005
# Spended time for 10 batches (total: 439)(320 images: 2.859584 sec
# Train Epoch: 1, Loss: 0.453275, Learning rate: 0.005
# Spended time for 10 batches (total: 449)(320 images: 2.073858 sec
# Train Epoch: 1, Loss: 0.486909, Learning rate: 0.005
# Spended time for 10 batches (total: 459)(320 images: 2.760622 sec
# Train Epoch: 1, Loss: 0.449345, Learning rate: 0.005
# Spended time for 10 batches (total: 469)(320 images: 2.863474 sec
# Train Epoch: 1, Loss: 0.453194, Learning rate: 0.005
# Spended time for 10 batches (total: 479)(320 images: 1.688960 sec
# Train Epoch: 1, Loss: 0.478859, Learning rate: 0.005
# Spended time for 10 batches (total: 489)(320 images: 1.596922 sec
# Train Epoch: 1, Loss: 0.416021, Learning rate: 0.005
# Spended time for 10 batches (total: 499)(320 images: 1.608213 sec
# Train Epoch: 1, Loss: 0.481847, Learning rate: 0.005
# Spended time for 10 batches (total: 509)(320 images: 1.590588 sec
# Train Epoch: 1, Loss: 0.527317, Learning rate: 0.005
# Spended time for 10 batches (total: 519)(320 images: 1.590065 sec
# Train Epoch: 1, Loss: 0.500036, Learning rate: 0.005
# Spended time for 10 batches (total: 529)(320 images: 1.591432 sec
# Train Epoch: 1, Loss: 0.429213, Learning rate: 0.005
# Spended time for 10 batches (total: 539)(320 images: 1.598992 sec
# Train Epoch: 1, Loss: 0.466060, Learning rate: 0.005
# Spended time for 10 batches (total: 549)(320 images: 1.599318 sec
# Train Epoch: 1, Loss: 0.457579, Learning rate: 0.005
# Spended time for 10 batches (total: 559)(320 images: 1.649425 sec
# Train Epoch: 1, Loss: 0.496591, Learning rate: 0.005
# Spended time for 10 batches (total: 569)(320 images: 2.542392 sec
# Train Epoch: 1, Loss: 0.497550, Learning rate: 0.005
# Spended time for 10 batches (total: 579)(320 images: 1.846647 sec
# Train Epoch: 1, Loss: 0.467040, Learning rate: 0.005
# Spended time for 10 batches (total: 589)(320 images: 1.727835 sec
# Train Epoch: 1, Loss: 0.398929, Learning rate: 0.005
# Spended time for 10 batches (total: 599)(320 images: 1.665536 sec
# Train Epoch: 1, Loss: 0.515468, Learning rate: 0.005
# Spended time for 10 batches (total: 609)(320 images: 1.611462 sec
# Train Epoch: 1, Loss: 0.422134, Learning rate: 0.005
# Spended time for 10 batches (total: 619)(320 images: 1.609230 sec
# Train Epoch: 1, Loss: 0.497350, Learning rate: 0.005
# Spended time for 10 batches (total: 629)(320 images: 1.604831 sec
# Train Epoch: 1, Loss: 0.432547, Learning rate: 0.005
# Spended time for 10 batches (total: 639)(320 images: 1.598098 sec
# Train Epoch: 1, Loss: 0.487348, Learning rate: 0.005
# Spended time for 10 batches (total: 649)(320 images: 1.608494 sec
# Train Epoch: 1, Loss: 0.476986, Learning rate: 0.005
# Spended time for 10 batches (total: 659)(320 images: 1.614759 sec
# Train Epoch: 1, Loss: 0.435646, Learning rate: 0.005
# Spended time for 10 batches (total: 669)(320 images: 1.624421 sec
# Train Epoch: 1, Loss: 0.465765, Learning rate: 0.005
# Spended time for 10 batches (total: 679)(320 images: 1.610011 sec
# Train Epoch: 1, Loss: 0.457311, Learning rate: 0.005
# Spended time for 10 batches (total: 689)(320 images: 1.617472 sec
# Train Epoch: 1, Loss: 0.449088, Learning rate: 0.005
# Spended time for 10 batches (total: 699)(320 images: 1.613326 sec
# Train Epoch: 1, Loss: 0.411027, Learning rate: 0.005
# Spended time for 10 batches (total: 709)(320 images: 1.628035 sec
# Train Epoch: 1, Loss: 0.442012, Learning rate: 0.005
# Spended time for 10 batches (total: 719)(320 images: 1.612057 sec
# Train Epoch: 1, Loss: 0.443487, Learning rate: 0.005
# Spended time for 10 batches (total: 729)(320 images: 1.712475 sec
# Train Epoch: 1, Loss: 0.442145, Learning rate: 0.005
# Spended time for 10 batches (total: 739)(320 images: 1.819031 sec
# Train Epoch: 1, Loss: 0.441735, Learning rate: 0.005
# Spended time for 10 batches (total: 749)(320 images: 1.649333 sec
# Train Epoch: 1, Loss: 0.447733, Learning rate: 0.005
# Spended time for 10 batches (total: 759)(320 images: 1.618665 sec
# Train Epoch: 1, Loss: 0.460442, Learning rate: 0.005
# Spended time for 10 batches (total: 769)(320 images: 1.645969 sec
# Train Epoch: 1, Loss: 0.438543, Learning rate: 0.005
# Spended time for 10 batches (total: 779)(320 images: 1.614837 sec
# Train Epoch: 1, Loss: 0.442265, Learning rate: 0.005
# Spended time for 10 batches (total: 789)(320 images: 1.617918 sec
# Train Epoch: 1, Loss: 0.435544, Learning rate: 0.005
# Spended time for 10 batches (total: 799)(320 images: 1.617213 sec
# Train Epoch: 1, Loss: 0.440954, Learning rate: 0.005
# Spended time for 10 batches (total: 809)(320 images: 1.613983 sec
# Train Epoch: 1, Loss: 0.415668, Learning rate: 0.005
# Spended time for 10 batches (total: 819)(320 images: 1.610173 sec
# Train Epoch: 1, Loss: 0.427368, Learning rate: 0.005
# Spended time for 10 batches (total: 829)(320 images: 1.615180 sec
# Train Epoch: 1, Loss: 0.399778, Learning rate: 0.005
# Spended time for 10 batches (total: 839)(320 images: 1.614835 sec
# Train Epoch: 1, Loss: 0.435264, Learning rate: 0.005
# Spended time for 10 batches (total: 849)(320 images: 1.612913 sec
# Train Epoch: 1, Loss: 0.409984, Learning rate: 0.005
# Spended time for 10 batches (total: 859)(320 images: 1.610571 sec
# Train Epoch: 1, Loss: 0.452000, Learning rate: 0.005
# Spended time for 10 batches (total: 869)(320 images: 1.610919 sec
# Train Epoch: 1, Loss: 0.389121, Learning rate: 0.005
# Spended time for 10 batches (total: 879)(320 images: 1.618199 sec
# Train Epoch: 1, Loss: 0.423404, Learning rate: 0.005
# Spended time for 10 batches (total: 889)(320 images: 1.609865 sec
# Train Epoch: 1, Loss: 0.470387, Learning rate: 0.005
# Spended time for 10 batches (total: 899)(320 images: 1.615008 sec
# Train Epoch: 1, Loss: 0.452923, Learning rate: 0.005
# Spended time for 10 batches (total: 909)(320 images: 1.625552 sec
# Train Epoch: 1, Loss: 0.467507, Learning rate: 0.005
# Spended time for 10 batches (total: 919)(320 images: 1.703595 sec
# Train Epoch: 1, Loss: 0.424759, Learning rate: 0.005
# Spended time for 10 batches (total: 929)(320 images: 1.772610 sec
# Train Epoch: 1, Loss: 0.375776, Learning rate: 0.005
# Spended time for 10 batches (total: 939)(320 images: 1.744055 sec
# Train Epoch: 1, Loss: 0.440138, Learning rate: 0.005
# Spended time for 10 batches (total: 949)(320 images: 1.729440 sec
# Train Epoch: 1, Loss: 0.404536, Learning rate: 0.005
# Spended time for 10 batches (total: 959)(320 images: 1.751912 sec
# Train Epoch: 1, Loss: 0.438422, Learning rate: 0.005
# Spended time for 10 batches (total: 969)(320 images: 1.760421 sec
# Train Epoch: 1, Loss: 0.418309, Learning rate: 0.005
# Spended time for 10 batches (total: 979)(320 images: 1.850405 sec
# Train Epoch: 1, Loss: 0.419744, Learning rate: 0.005
# Spended time for 10 batches (total: 989)(320 images: 1.716144 sec
# Train Epoch: 1, Loss: 0.434759, Learning rate: 0.005
# Spended time for 10 batches (total: 999)(320 images: 1.717579 sec
# Train Epoch: 1, Loss: 0.432500, Learning rate: 0.005
# Spended time for 10 batches (total: 1009)(320 images: 1.740364 sec
# Train Epoch: 1, Loss: 0.391413, Learning rate: 0.005
# Spended time for 10 batches (total: 1019)(320 images: 1.750921 sec
# Train Epoch: 1, Loss: 0.434879, Learning rate: 0.005
# Spended time for 10 batches (total: 1029)(320 images: 1.891195 sec
# Train Epoch: 1, Loss: 0.441681, Learning rate: 0.005
# Spended time for 10 batches (total: 1039)(320 images: 1.948676 sec
# Train Epoch: 1, Loss: 0.413490, Learning rate: 0.005
# Spended time for 10 batches (total: 1049)(320 images: 1.721122 sec
# Train Epoch: 1, Loss: 0.402873, Learning rate: 0.005
# Spended time for 10 batches (total: 1059)(320 images: 1.762696 sec
# Train Epoch: 1, Loss: 0.434134, Learning rate: 0.005
# Spended time for 10 batches (total: 1069)(320 images: 1.732732 sec
# Train Epoch: 1, Loss: 0.406465, Learning rate: 0.005
# Spended time for 10 batches (total: 1079)(320 images: 1.837310 sec
# Train Epoch: 1, Loss: 0.437649, Learning rate: 0.005
# Spended time for 10 batches (total: 1089)(320 images: 1.671590 sec
# Train Epoch: 1, Loss: 0.423227, Learning rate: 0.005
# Spended time for 10 batches (total: 1099)(320 images: 1.624034 sec
# Train Epoch: 1, Loss: 0.435777, Learning rate: 0.005
# Spended time for 10 batches (total: 1109)(320 images: 1.618409 sec
# Train Epoch: 1, Loss: 0.382188, Learning rate: 0.005
# Spended time for 10 batches (total: 1119)(320 images: 1.641077 sec
# Train Epoch: 1, Loss: 0.409666, Learning rate: 0.005
# Spended time for 10 batches (total: 1129)(320 images: 1.658625 sec
# Train Epoch: 1, Loss: 0.397444, Learning rate: 0.005
# Spended time for 10 batches (total: 1139)(320 images: 1.625136 sec
# Train Epoch: 1, Loss: 0.391970, Learning rate: 0.005
# Spended time for 10 batches (total: 1149)(320 images: 1.624530 sec
# Train Epoch: 1, Loss: 0.410069, Learning rate: 0.005
# Spended time for 10 batches (total: 1159)(320 images: 1.644986 sec
# Train Epoch: 1, Loss: 0.403337, Learning rate: 0.005
# Spended time for 10 batches (total: 1169)(320 images: 1.642155 sec
# Train Epoch: 1, Loss: 0.408245, Learning rate: 0.005
# Spended time for 10 batches (total: 1179)(320 images: 1.662058 sec
# Train Epoch: 1, Loss: 0.433970, Learning rate: 0.005
# Spended time for 10 batches (total: 1189)(320 images: 1.666996 sec
# Train Epoch: 1, Loss: 0.382282, Learning rate: 0.005
# Spended time for 10 batches (total: 1199)(320 images: 1.929165 sec
# Train Epoch: 1, Loss: 0.463536, Learning rate: 0.005
# Spended time for 10 batches (total: 1209)(320 images: 1.672721 sec
# Train Epoch: 1, Loss: 0.431503, Learning rate: 0.005
# Spended time for 10 batches (total: 1219)(320 images: 1.780627 sec
# Train Epoch: 1, Loss: 0.414923, Learning rate: 0.005
# Spended time for 10 batches (total: 1229)(320 images: 1.647107 sec
# Train Epoch: 1, Loss: 0.397645, Learning rate: 0.005
# Spended time for 10 batches (total: 1239)(320 images: 1.629534 sec
# Train Epoch: 1, Loss: 0.367240, Learning rate: 0.005
# Spended time for 10 batches (total: 1249)(320 images: 1.618774 sec
# Train Epoch: 1, Loss: 0.393168, Learning rate: 0.005
# Spended time for 10 batches (total: 1259)(320 images: 1.737024 sec
# Train Epoch: 1, Loss: 0.398094, Learning rate: 0.005
# Spended time for 10 batches (total: 1269)(320 images: 1.923422 sec
# Train Epoch: 1, Loss: 0.456147, Learning rate: 0.005
# Spended time for 10 batches (total: 1279)(320 images: 1.799186 sec
# Train Epoch: 1, Loss: 0.433140, Learning rate: 0.005
# Spended time for 10 batches (total: 1289)(320 images: 1.784106 sec
# Train Epoch: 1, Loss: 0.403693, Learning rate: 0.005
# Spended time for 10 batches (total: 1299)(320 images: 1.815046 sec
# Train Epoch: 1, Loss: 0.424731, Learning rate: 0.005
# Spended time for 10 batches (total: 1309)(320 images: 1.777003 sec
# Train Epoch: 1, Loss: 0.406995, Learning rate: 0.005
# Spended time for 10 batches (total: 1319)(320 images: 1.840421 sec
# Train Epoch: 1, Loss: 0.445156, Learning rate: 0.005
# Spended time for 10 batches (total: 1329)(320 images: 1.725661 sec
# Train Epoch: 1, Loss: 0.442228, Learning rate: 0.005
# Spended time for 10 batches (total: 1339)(320 images: 1.729373 sec
# Train Epoch: 1, Loss: 0.424744, Learning rate: 0.005
# Spended time for 10 batches (total: 1349)(320 images: 1.758679 sec
# Train Epoch: 1, Loss: 0.429293, Learning rate: 0.005
# Spended time for 10 batches (total: 1359)(320 images: 1.753998 sec
# Train Epoch: 1, Loss: 0.423970, Learning rate: 0.005
# Spended time for 10 batches (total: 1369)(320 images: 1.845362 sec
# Train Epoch: 1, Loss: 0.443020, Learning rate: 0.005
# Spended time for 10 batches (total: 1379)(320 images: 1.730893 sec
# Train Epoch: 1, Loss: 0.426126, Learning rate: 0.005
# Spended time for 10 batches (total: 1389)(320 images: 1.739915 sec
# Train Epoch: 1, Loss: 0.361969, Learning rate: 0.005
# Spended time for 10 batches (total: 1399)(320 images: 1.742740 sec
# Train Epoch: 1, Loss: 0.415846, Learning rate: 0.005
# Spended time for 10 batches (total: 1409)(320 images: 1.776116 sec
# Train Epoch: 1, Loss: 0.371883, Learning rate: 0.005
# Spended time for 10 batches (total: 1419)(320 images: 1.843126 sec
# Train Epoch: 1, Loss: 0.425330, Learning rate: 0.005
# Spended time for 10 batches (total: 1429)(320 images: 2.066815 sec
# Train Epoch: 1, Loss: 0.435885, Learning rate: 0.005
# Spended time for 10 batches (total: 1439)(320 images: 1.630851 sec
# Train Epoch: 1, Loss: 0.410045, Learning rate: 0.005
# Spended time for 10 batches (total: 1449)(320 images: 1.630034 sec
# Train Epoch: 1, Loss: 0.405954, Learning rate: 0.005
# Spended time for 10 batches (total: 1459)(320 images: 1.623873 sec
# Train Epoch: 1, Loss: 0.438290, Learning rate: 0.005
# Spended time for 10 batches (total: 1469)(320 images: 1.661128 sec
# Train Epoch: 1, Loss: 0.387147, Learning rate: 0.005
# Spended time for 10 batches (total: 1479)(320 images: 1.621258 sec
# Train Epoch: 1, Loss: 0.449953, Learning rate: 0.005
# Spended time for 10 batches (total: 1489)(320 images: 1.631259 sec
# Train Epoch: 1, Loss: 0.454753, Learning rate: 0.005
# Spended time for 10 batches (total: 1499)(320 images: 1.640353 sec
# Train Epoch: 1, Loss: 0.458245, Learning rate: 0.005
# Spended time for 10 batches (total: 1509)(320 images: 1.615750 sec
# Train Epoch: 1, Loss: 0.405264, Learning rate: 0.005
# Spended time for 10 batches (total: 1519)(320 images: 1.639384 sec
# Train Epoch: 1, Loss: 0.428931, Learning rate: 0.005
# Spended time for 10 batches (total: 1529)(320 images: 1.640713 sec
# Train Epoch: 1, Loss: 0.412770, Learning rate: 0.005
# Spended time for 10 batches (total: 1539)(320 images: 1.653212 sec
# Train Epoch: 1, Loss: 0.395810, Learning rate: 0.005
# Spended time for 10 batches (total: 1549)(320 images: 1.662571 sec
# Train Epoch: 1, Loss: 0.444857, Learning rate: 0.005
# Spended time for 10 batches (total: 1559)(320 images: 1.694261 sec
# Train Epoch: 1, Loss: 0.434788, Learning rate: 0.005
# Spended time for 10 batches (total: 1569)(320 images: 1.848023 sec
# Train Epoch: 1, Loss: 0.386296, Learning rate: 0.005
# Spended time for 10 batches (total: 1579)(320 images: 1.739565 sec
# Train Epoch: 1, Loss: 0.457240, Learning rate: 0.005
# Spended time for 10 batches (total: 1589)(320 images: 2.078022 sec
# Train Epoch: 1, Loss: 0.346930, Learning rate: 0.005
# Spended time for 10 batches (total: 1599)(320 images: 1.859464 sec
# Train Epoch: 1, Loss: 0.349268, Learning rate: 0.005
# Spended time for 10 batches (total: 1609)(320 images: 1.952973 sec
# Train Epoch: 1, Loss: 0.381701, Learning rate: 0.005
# Spended time for 10 batches (total: 1619)(320 images: 1.732404 sec
# Train Epoch: 1, Loss: 0.433695, Learning rate: 0.005
# Spended time for 10 batches (total: 1629)(320 images: 1.750062 sec
# Train Epoch: 1, Loss: 0.403033, Learning rate: 0.005
# Spended time for 10 batches (total: 1639)(320 images: 1.809361 sec
# Train Epoch: 1, Loss: 0.404900, Learning rate: 0.005
# Spended time for 10 batches (total: 1649)(320 images: 1.838704 sec
# Train Epoch: 1, Loss: 0.425177, Learning rate: 0.005
# Spended time for 10 batches (total: 1659)(320 images: 1.984570 sec
# Train Epoch: 1, Loss: 0.423480, Learning rate: 0.005
# Spended time for 10 batches (total: 1669)(320 images: 1.764440 sec
# Train Epoch: 1, Loss: 0.420677, Learning rate: 0.005
# Spended time for 10 batches (total: 1679)(320 images: 1.820719 sec
# Train Epoch: 1, Loss: 0.431450, Learning rate: 0.005
# Spended time for 10 batches (total: 1689)(320 images: 1.782375 sec
# Train Epoch: 1, Loss: 0.412124, Learning rate: 0.005
# Spended time for 10 batches (total: 1699)(320 images: 1.825505 sec
# Train Epoch: 1, Loss: 0.362439, Learning rate: 0.005
# Spended time for 10 batches (total: 1709)(320 images: 1.889152 sec
# Train Epoch: 1, Loss: 0.355833, Learning rate: 0.005
# Spended time for 10 batches (total: 1719)(320 images: 1.770832 sec
# Train Epoch: 1, Loss: 0.331247, Learning rate: 0.005
# Spended time for 10 batches (total: 1729)(320 images: 1.674895 sec
# Train Epoch: 1, Loss: 0.446461, Learning rate: 0.005
# Spended time for 10 batches (total: 1739)(320 images: 1.716565 sec
# Train Epoch: 1, Loss: 0.417392, Learning rate: 0.005
# Spended time for 10 batches (total: 1749)(320 images: 1.661878 sec
# Train Epoch: 1, Loss: 0.396711, Learning rate: 0.005
# Spended time for 10 batches (total: 1759)(320 images: 1.699457 sec
# Train Epoch: 1, Loss: 0.430326, Learning rate: 0.005
# Spended time for 10 batches (total: 1769)(320 images: 1.736890 sec
# Train Epoch: 1, Loss: 0.331580, Learning rate: 0.005
# Spended time for 10 batches (total: 1779)(320 images: 1.722072 sec
# Train Epoch: 1, Loss: 0.440683, Learning rate: 0.005
# Spended time for 10 batches (total: 1789)(320 images: 1.708114 sec
# Train Epoch: 1, Loss: 0.448256, Learning rate: 0.005
# Spended time for 10 batches (total: 1799)(320 images: 1.737748 sec
# Train Epoch: 1, Loss: 0.360022, Learning rate: 0.005
# Spended time for 10 batches (total: 1809)(320 images: 1.708243 sec
# Train Epoch: 1, Loss: 0.345617, Learning rate: 0.005
# Spended time for 10 batches (total: 1819)(320 images: 1.649983 sec
# Train Epoch: 1, Loss: 0.405799, Learning rate: 0.005
# Spended time for 10 batches (total: 1829)(320 images: 1.697937 sec
# Train Epoch: 1, Loss: 0.447774, Learning rate: 0.005
# Spended time for 10 batches (total: 1839)(320 images: 1.657740 sec
# Train Epoch: 1, Loss: 0.377119, Learning rate: 0.005
# Spended time for 10 batches (total: 1849)(320 images: 1.653265 sec
# Train Epoch: 1, Loss: 0.410952, Learning rate: 0.005
# Spended time for 10 batches (total: 1859)(320 images: 1.779114 sec
# Train Epoch: 1, Loss: 0.363734, Learning rate: 0.005
# Spended time for 10 batches (total: 1869)(320 images: 1.868944 sec
# Train Epoch: 1, Loss: 0.406236, Learning rate: 0.005
# Spended time for 10 batches (total: 1879)(320 images: 1.783433 sec
# Train Epoch: 1, Loss: 0.395750, Learning rate: 0.005
# Spended time for 10 batches (total: 1889)(320 images: 2.826602 sec
# Train Epoch: 1, Loss: 0.373805, Learning rate: 0.005
# Spended time for 10 batches (total: 1899)(320 images: 2.226302 sec
# Train Epoch: 1, Loss: 0.345121, Learning rate: 0.005
# Spended time for 10 batches (total: 1909)(320 images: 1.937178 sec
# Train Epoch: 1, Loss: 0.413630, Learning rate: 0.005
# Spended time for 10 batches (total: 1919)(320 images: 1.808717 sec
# Train Epoch: 1, Loss: 0.416946, Learning rate: 0.005
# Spended time for 10 batches (total: 1929)(320 images: 1.760571 sec
# Train Epoch: 1, Loss: 0.362608, Learning rate: 0.005
# Spended time for 10 batches (total: 1939)(320 images: 1.880173 sec
# Train Epoch: 1, Loss: 0.408762, Learning rate: 0.005
# Spended time for 10 batches (total: 1949)(320 images: 1.899848 sec
# Train Epoch: 1, Loss: 0.411237, Learning rate: 0.005
# Spended time for 10 batches (total: 1959)(320 images: 1.830809 sec
# Train Epoch: 1, Loss: 0.372035, Learning rate: 0.005
# Spended time for 10 batches (total: 1969)(320 images: 1.933322 sec
# Train Epoch: 1, Loss: 0.425484, Learning rate: 0.005
# Spended time for 10 batches (total: 1979)(320 images: 1.737115 sec
# Train Epoch: 1, Loss: 0.381506, Learning rate: 0.005
# Spended time for 10 batches (total: 1989)(320 images: 1.790227 sec
# Train Epoch: 1, Loss: 0.451467, Learning rate: 0.005
# Spended time for 10 batches (total: 1999)(320 images: 1.835024 sec
# Train Epoch: 1, Loss: 0.403900, Learning rate: 0.005
# Spended time for 10 batches (total: 2009)(320 images: 1.823127 sec
# Train Epoch: 1, Loss: 0.398788, Learning rate: 0.005
# Spended time for 10 batches (total: 2019)(320 images: 1.882882 sec
# Train Epoch: 1, Loss: 0.411926, Learning rate: 0.005
# Spended time for 10 batches (total: 2029)(320 images: 1.707085 sec
# Train Epoch: 1, Loss: 0.415944, Learning rate: 0.005
# Spended time for 10 batches (total: 2039)(320 images: 1.657650 sec
# Train Epoch: 1, Loss: 0.404301, Learning rate: 0.005
# Spended time for 10 batches (total: 2049)(320 images: 1.674679 sec
# Train Epoch: 1, Loss: 0.411143, Learning rate: 0.005
# Spended time for 10 batches (total: 2059)(320 images: 1.639156 sec
# Train Epoch: 1, Loss: 0.392245, Learning rate: 0.005
# Spended time for 10 batches (total: 2069)(320 images: 1.631421 sec
# Train Epoch: 1, Loss: 0.405884, Learning rate: 0.005
# Spended time for 10 batches (total: 2079)(320 images: 1.666033 sec
# Train Epoch: 1, Loss: 0.412291, Learning rate: 0.005
# Spended time for 10 batches (total: 2089)(320 images: 1.661654 sec
# Train Epoch: 1, Loss: 0.386956, Learning rate: 0.005
# Spended time for 10 batches (total: 2099)(320 images: 1.712415 sec
# Train Epoch: 1, Loss: 0.451807, Learning rate: 0.005
# Spended time for 10 batches (total: 2109)(320 images: 1.682629 sec
# Train Epoch: 1, Loss: 0.392231, Learning rate: 0.005
# Spended time for 10 batches (total: 2119)(320 images: 1.721936 sec
# Train Epoch: 1, Loss: 0.399498, Learning rate: 0.005
# Spended time for 10 batches (total: 2129)(320 images: 1.736831 sec
# Train Epoch: 1, Loss: 0.478323, Learning rate: 0.005
# Spended time for 10 batches (total: 2139)(320 images: 1.755080 sec
# Train Epoch: 1, Loss: 0.400929, Learning rate: 0.005
# Spended time for 10 batches (total: 2149)(320 images: 1.748978 sec
# Train Epoch: 1, Loss: 0.432278, Learning rate: 0.005
# Spended time for 10 batches (total: 2159)(320 images: 1.693342 sec
# Train Epoch: 1, Loss: 0.416489, Learning rate: 0.005
# Spended time for 10 batches (total: 2169)(320 images: 1.735139 sec
# Train Epoch: 1, Loss: 0.392727, Learning rate: 0.005
# Spended time for 10 batches (total: 2179)(320 images: 1.706029 sec
# Train Epoch: 1, Loss: 0.373438, Learning rate: 0.005
# Spended time for 10 batches (total: 2189)(320 images: 1.732305 sec
# Train Epoch: 1, Loss: 0.438571, Learning rate: 0.005
# Spended time for 10 batches (total: 2199)(320 images: 1.731052 sec
# Train Epoch: 1, Loss: 0.385170, Learning rate: 0.005
# Spended time for 10 batches (total: 2209)(320 images: 1.722287 sec
# Train Epoch: 1, Loss: 0.425641, Learning rate: 0.005
# Spended time for 10 batches (total: 2219)(320 images: 1.778816 sec
# Train Epoch: 1, Loss: 0.395592, Learning rate: 0.005
# Spended time for 10 batches (total: 2229)(320 images: 1.782792 sec
# Train Epoch: 1, Loss: 0.430898, Learning rate: 0.005
# Spended time for 10 batches (total: 2239)(320 images: 1.922147 sec
# Train Epoch: 1, Loss: 0.383759, Learning rate: 0.005
# Spended time for 10 batches (total: 2249)(320 images: 1.826476 sec
# Train Epoch: 1, Loss: 0.408042, Learning rate: 0.005
# Spended time for 10 batches (total: 2259)(320 images: 1.782189 sec
# Train Epoch: 1, Loss: 0.359165, Learning rate: 0.005
# Spended time for 10 batches (total: 2269)(320 images: 1.853452 sec
# Train Epoch: 1, Loss: 0.397889, Learning rate: 0.005
# Spended time for 10 batches (total: 2279)(320 images: 1.946986 sec
# Train Epoch: 1, Loss: 0.382631, Learning rate: 0.005
# Spended time for 10 batches (total: 2289)(320 images: 1.755797 sec
# Train Epoch: 1, Loss: 0.374991, Learning rate: 0.005
# Spended time for 10 batches (total: 2299)(320 images: 1.790015 sec
# Train Epoch: 1, Loss: 0.365675, Learning rate: 0.005
# Spended time for 10 batches (total: 2309)(320 images: 1.830731 sec
# Train Epoch: 1, Loss: 0.346995, Learning rate: 0.005
# Spended time for 10 batches (total: 2319)(320 images: 1.831043 sec
# Train Epoch: 1, Loss: 0.418697, Learning rate: 0.005
# Spended time for 10 batches (total: 2329)(320 images: 1.925251 sec
# Train Epoch: 1, Loss: 0.405769, Learning rate: 0.005
# Spended time for 10 batches (total: 2339)(320 images: 1.756970 sec
# Train Epoch: 1, Loss: 0.395693, Learning rate: 0.005
# Spended time for 10 batches (total: 2349)(320 images: 1.779704 sec
# Train Epoch: 1, Loss: 0.378504, Learning rate: 0.005
# Spended time for 10 batches (total: 2359)(320 images: 1.819274 sec
# Train Epoch: 1, Loss: 0.348648, Learning rate: 0.005
# Spended time for 10 batches (total: 2369)(320 images: 1.841418 sec
# Train Epoch: 1, Loss: 0.420063, Learning rate: 0.005
# Spended time for 10 batches (total: 2379)(320 images: 1.915561 sec
# Train Epoch: 1, Loss: 0.403875, Learning rate: 0.005
# Spended time for 10 batches (total: 2389)(320 images: 1.789459 sec
# Train Epoch: 1, Loss: 0.376698, Learning rate: 0.005
# Spended time for 10 batches (total: 2399)(320 images: 1.681240 sec
# Train Epoch: 1, Loss: 0.340052, Learning rate: 0.005
# Spended time for 10 batches (total: 2409)(320 images: 1.677143 sec
# Train Epoch: 1, Loss: 0.397930, Learning rate: 0.005
# Spended time for 10 batches (total: 2419)(320 images: 1.684661 sec
# Train Epoch: 1, Loss: 0.366608, Learning rate: 0.005
# Spended time for 10 batches (total: 2429)(320 images: 2.510851 sec
# Train Epoch: 1, Loss: 0.392767, Learning rate: 0.005
# Spended time for 10 batches (total: 2439)(320 images: 1.919938 sec
# Train Epoch: 1, Loss: 0.365937, Learning rate: 0.005
# Spended time for 10 batches (total: 2449)(320 images: 1.737087 sec
# Train Epoch: 1, Loss: 0.339769, Learning rate: 0.005
# Spended time for 10 batches (total: 2459)(320 images: 1.790001 sec
# Train Epoch: 1, Loss: 0.358609, Learning rate: 0.005
# Spended time for 10 batches (total: 2469)(320 images: 1.872531 sec
# Train Epoch: 1, Loss: 0.391556, Learning rate: 0.005
# Spended time for 10 batches (total: 2479)(320 images: 1.723881 sec
# Train Epoch: 1, Loss: 0.442205, Learning rate: 0.005
# Spended time for 10 batches (total: 2489)(320 images: 1.724157 sec
# Train Epoch: 1, Loss: 0.395963, Learning rate: 0.005
# Spended time for 10 batches (total: 2499)(320 images: 1.707027 sec
# Train Epoch: 1, Loss: 0.440596, Learning rate: 0.005
# Spended time for 10 batches (total: 2509)(320 images: 1.700527 sec
# Train Epoch: 1, Loss: 0.410789, Learning rate: 0.005
# Spended time for 10 batches (total: 2519)(320 images: 1.729981 sec
# Train Epoch: 1, Loss: 0.384413, Learning rate: 0.005
# Spended time for 10 batches (total: 2529)(320 images: 1.712667 sec
# Train Epoch: 1, Loss: 0.392107, Learning rate: 0.005
# Spended time for 10 batches (total: 2539)(320 images: 1.859280 sec
# Train Epoch: 1, Loss: 0.366519, Learning rate: 0.005
# Spended time for 10 batches (total: 2549)(320 images: 1.831208 sec
# Train Epoch: 1, Loss: 0.403364, Learning rate: 0.005
# Spended time for 10 batches (total: 2559)(320 images: 1.919571 sec
# Train Epoch: 1, Loss: 0.434882, Learning rate: 0.005
# Spended time for 10 batches (total: 2569)(320 images: 1.817549 sec
# Train Epoch: 1, Loss: 0.377970, Learning rate: 0.005
# Spended time for 10 batches (total: 2579)(320 images: 1.797216 sec
# Train Epoch: 1, Loss: 0.476555, Learning rate: 0.005
# Spended time for 10 batches (total: 2589)(320 images: 1.796370 sec
# Train Epoch: 1, Loss: 0.374418, Learning rate: 0.005
# Spended time for 10 batches (total: 2599)(320 images: 1.822568 sec
# Train Epoch: 1, Loss: 0.402385, Learning rate: 0.005
# Spended time for 10 batches (total: 2609)(320 images: 2.080409 sec
# Train Epoch: 1, Loss: 0.402144, Learning rate: 0.005
# Spended time for 10 batches (total: 2619)(320 images: 1.798622 sec
# Train Epoch: 1, Loss: 0.433814, Learning rate: 0.005
# Spended time for 10 batches (total: 2629)(320 images: 1.839330 sec
# Train Epoch: 1, Loss: 0.425416, Learning rate: 0.005
# Spended time for 10 batches (total: 2639)(320 images: 1.786070 sec
# Train Epoch: 1, Loss: 0.394333, Learning rate: 0.005
# Spended time for 10 batches (total: 2649)(320 images: 1.769987 sec
# Train Epoch: 1, Loss: 0.383438, Learning rate: 0.005
# Spended time for 10 batches (total: 2659)(320 images: 1.879660 sec
# Train Epoch: 1, Loss: 0.336908, Learning rate: 0.005
# Spended time for 10 batches (total: 2669)(320 images: 1.978115 sec
# Train Epoch: 1, Loss: 0.409975, Learning rate: 0.005
# Spended time for 10 batches (total: 2679)(320 images: 1.841636 sec
# Train Epoch: 1, Loss: 0.376016, Learning rate: 0.005
# Spended time for 10 batches (total: 2689)(320 images: 1.825438 sec
# Train Epoch: 1, Loss: 0.350178, Learning rate: 0.005
# Spended time for 10 batches (total: 2699)(320 images: 1.870878 sec
# Train Epoch: 1, Loss: 0.371541, Learning rate: 0.005
# Spended time for 10 batches (total: 2709)(320 images: 1.848701 sec
# Train Epoch: 1, Loss: 0.431864, Learning rate: 0.005
# Spended time for 10 batches (total: 2719)(320 images: 1.866074 sec
# Train Epoch: 1, Loss: 0.419364, Learning rate: 0.005
# Spended time for 10 batches (total: 2729)(320 images: 1.957446 sec
# Train Epoch: 1, Loss: 0.397194, Learning rate: 0.005
# Spended time for 10 batches (total: 2739)(320 images: 1.782478 sec
# Train Epoch: 1, Loss: 0.364278, Learning rate: 0.005
# Spended time for 10 batches (total: 2749)(320 images: 1.819222 sec
# Train Epoch: 1, Loss: 0.387503, Learning rate: 0.005
# Spended time for 10 batches (total: 2759)(320 images: 1.765893 sec
# Train Epoch: 1, Loss: 0.361897, Learning rate: 0.005
# Spended time for 10 batches (total: 2769)(320 images: 1.766236 sec
# Train Epoch: 1, Loss: 0.391099, Learning rate: 0.005
# Spended time for 10 batches (total: 2779)(320 images: 1.815799 sec
# Train Epoch: 1, Loss: 0.401337, Learning rate: 0.005
# Spended time for 10 batches (total: 2789)(320 images: 1.784334 sec
# Train Epoch: 1, Loss: 0.357466, Learning rate: 0.005
# Spended time for 10 batches (total: 2799)(320 images: 1.814407 sec
# Train Epoch: 1, Loss: 0.330602, Learning rate: 0.005
# Spended time for 10 batches (total: 2809)(320 images: 1.793666 sec
# Train Epoch: 1, Loss: 0.367720, Learning rate: 0.005
# Spended time for 10 batches (total: 2819)(320 images: 1.693008 sec
# Train Epoch: 1, Loss: 0.337677, Learning rate: 0.005
# Spended time for 10 batches (total: 2829)(320 images: 1.746149 sec
# Train Epoch: 1, Loss: 0.363956, Learning rate: 0.005
# Spended time for 10 batches (total: 2839)(320 images: 1.783944 sec
# Train Epoch: 1, Loss: 0.380858, Learning rate: 0.005
# Spended time for 10 batches (total: 2849)(320 images: 1.769237 sec
# Train Epoch: 1, Loss: 0.401232, Learning rate: 0.005
# Spended time for 10 batches (total: 2859)(320 images: 1.736169 sec
# Train Epoch: 1, Loss: 0.374599, Learning rate: 0.005
# Spended time for 10 batches (total: 2869)(320 images: 1.697512 sec
# Train Epoch: 1, Loss: 0.373879, Learning rate: 0.005
# Spended time for 10 batches (total: 2879)(320 images: 1.718301 sec
# Train Epoch: 1, Loss: 0.413584, Learning rate: 0.005
# Spended time for 10 batches (total: 2889)(320 images: 1.835285 sec
# Train Epoch: 1, Loss: 0.373003, Learning rate: 0.005
# Spended time for 10 batches (total: 2899)(320 images: 1.865709 sec
# Train Epoch: 1, Loss: 0.393994, Learning rate: 0.005
# Spended time for 10 batches (total: 2909)(320 images: 1.907739 sec
# Train Epoch: 1, Loss: 0.404892, Learning rate: 0.005
# Spended time for 10 batches (total: 2919)(320 images: 1.813328 sec
# Train Epoch: 1, Loss: 0.359243, Learning rate: 0.005
# Spended time for 10 batches (total: 2929)(320 images: 1.826374 sec
# Train Epoch: 1, Loss: 0.422332, Learning rate: 0.005
# Spended time for 10 batches (total: 2939)(320 images: 1.860442 sec
# Train Epoch: 1, Loss: 0.404394, Learning rate: 0.005
# Spended time for 10 batches (total: 2949)(320 images: 1.909728 sec
# Train Epoch: 1, Loss: 0.388901, Learning rate: 0.005
# Spended time for 10 batches (total: 2959)(320 images: 1.943413 sec
# Train Epoch: 1, Loss: 0.403273, Learning rate: 0.005
# Spended time for 10 batches (total: 2969)(320 images: 1.838498 sec
# Train Epoch: 1, Loss: 0.373094, Learning rate: 0.005
# Spended time for 10 batches (total: 2979)(320 images: 1.890933 sec
# Train Epoch: 1, Loss: 0.386222, Learning rate: 0.005
# Spended time for 10 batches (total: 2989)(320 images: 1.823725 sec
# Train Epoch: 1, Loss: 0.420290, Learning rate: 0.005
# Spended time for 10 batches (total: 2999)(320 images: 1.852353 sec
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:133: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ================================================================================
# Epoch 1, train loss: 0.426965, valid loss: 0.390332, valid metric: 0.904531
# ================================================================================
# Train Epoch: 1, Loss: 0.392296, Learning rate: 0.005
# Spended time for 10 batches (total: 3009)(320 images: 44.321067 sec
# Train Epoch: 1, Loss: 0.415090, Learning rate: 0.005
# Spended time for 10 batches (total: 3019)(320 images: 1.847962 sec
# Train Epoch: 1, Loss: 0.330858, Learning rate: 0.005
# Spended time for 10 batches (total: 3029)(320 images: 1.903555 sec
# Train Epoch: 1, Loss: 0.397980, Learning rate: 0.005
# Spended time for 10 batches (total: 3039)(320 images: 1.898943 sec
# Train Epoch: 1, Loss: 0.336021, Learning rate: 0.005
# Spended time for 10 batches (total: 3049)(320 images: 2.001597 sec
# Train Epoch: 1, Loss: 0.387447, Learning rate: 0.005
# Spended time for 10 batches (total: 3059)(320 images: 1.918789 sec
# Train Epoch: 1, Loss: 0.393433, Learning rate: 0.005
# Spended time for 10 batches (total: 3069)(320 images: 1.798514 sec
# Train Epoch: 1, Loss: 0.444521, Learning rate: 0.005
# Spended time for 10 batches (total: 3079)(320 images: 1.803732 sec
# Train Epoch: 1, Loss: 0.388926, Learning rate: 0.005
# Spended time for 10 batches (total: 3089)(320 images: 1.817474 sec
# Train Epoch: 1, Loss: 0.342230, Learning rate: 0.005
# Spended time for 10 batches (total: 3099)(320 images: 1.807169 sec
# Train Epoch: 1, Loss: 0.383487, Learning rate: 0.005
# Spended time for 10 batches (total: 3109)(320 images: 1.809530 sec
# Train Epoch: 1, Loss: 0.366225, Learning rate: 0.005
# Spended time for 10 batches (total: 3119)(320 images: 1.864981 sec
# Train Epoch: 1, Loss: 0.419584, Learning rate: 0.005
# Spended time for 10 batches (total: 3129)(320 images: 1.988003 sec
# Train Epoch: 1, Loss: 0.388541, Learning rate: 0.005
# Spended time for 10 batches (total: 3139)(320 images: 1.918669 sec
# Train Epoch: 1, Loss: 0.379776, Learning rate: 0.005
# Spended time for 10 batches (total: 3149)(320 images: 1.825992 sec
# Train Epoch: 1, Loss: 0.418077, Learning rate: 0.005
# Spended time for 10 batches (total: 3159)(320 images: 1.883808 sec
# Train Epoch: 1, Loss: 0.391826, Learning rate: 0.005
# Spended time for 10 batches (total: 3169)(320 images: 1.791730 sec
# Train Epoch: 1, Loss: 0.391158, Learning rate: 0.005
# Spended time for 10 batches (total: 3179)(320 images: 1.868502 sec
# Train Epoch: 1, Loss: 0.402544, Learning rate: 0.005
# Spended time for 10 batches (total: 3189)(320 images: 1.807289 sec
# Train Epoch: 1, Loss: 0.402759, Learning rate: 0.005
# Spended time for 10 batches (total: 3199)(320 images: 1.901546 sec
# Train Epoch: 1, Loss: 0.352105, Learning rate: 0.005
# Spended time for 10 batches (total: 3209)(320 images: 2.033045 sec
# Train Epoch: 1, Loss: 0.376118, Learning rate: 0.005
# Spended time for 10 batches (total: 3219)(320 images: 1.882233 sec
# Train Epoch: 1, Loss: 0.441675, Learning rate: 0.005
# Spended time for 10 batches (total: 3229)(320 images: 1.840320 sec
# Train Epoch: 1, Loss: 0.439683, Learning rate: 0.005
# Spended time for 10 batches (total: 3239)(320 images: 1.810608 sec
# Train Epoch: 1, Loss: 0.404683, Learning rate: 0.005
# Spended time for 10 batches (total: 3249)(320 images: 1.844944 sec
# Train Epoch: 1, Loss: 0.388078, Learning rate: 0.005
# Spended time for 10 batches (total: 3259)(320 images: 1.735231 sec
# Train Epoch: 1, Loss: 0.400420, Learning rate: 0.005
# Spended time for 10 batches (total: 3269)(320 images: 1.772007 sec
# Train Epoch: 1, Loss: 0.359633, Learning rate: 0.005
# Spended time for 10 batches (total: 3279)(320 images: 1.790371 sec
# Train Epoch: 1, Loss: 0.430689, Learning rate: 0.005
# Spended time for 10 batches (total: 3289)(320 images: 1.845701 sec
# Train Epoch: 1, Loss: 0.416970, Learning rate: 0.005
# Spended time for 10 batches (total: 3299)(320 images: 1.855290 sec
# Train Epoch: 1, Loss: 0.416549, Learning rate: 0.005
# Spended time for 10 batches (total: 3309)(320 images: 1.858960 sec
# Train Epoch: 1, Loss: 0.409633, Learning rate: 0.005
# Spended time for 10 batches (total: 3319)(320 images: 1.799544 sec
# Train Epoch: 1, Loss: 0.386680, Learning rate: 0.005
# Spended time for 10 batches (total: 3329)(320 images: 1.758220 sec
# Train Epoch: 1, Loss: 0.365613, Learning rate: 0.005
# Spended time for 10 batches (total: 3339)(320 images: 1.802696 sec
# Train Epoch: 1, Loss: 0.379177, Learning rate: 0.005
# Spended time for 10 batches (total: 3349)(320 images: 1.861662 sec
# Train Epoch: 1, Loss: 0.380816, Learning rate: 0.005
# Spended time for 10 batches (total: 3359)(320 images: 1.988597 sec
# Train Epoch: 1, Loss: 0.330521, Learning rate: 0.005
# Spended time for 10 batches (total: 3369)(320 images: 1.833037 sec
# Train Epoch: 1, Loss: 0.405983, Learning rate: 0.005
# Spended time for 10 batches (total: 3379)(320 images: 1.860193 sec
# Train Epoch: 1, Loss: 0.442477, Learning rate: 0.005
# Spended time for 10 batches (total: 3389)(320 images: 1.862658 sec
# Train Epoch: 1, Loss: 0.375343, Learning rate: 0.005
# Spended time for 10 batches (total: 3399)(320 images: 2.002373 sec
# Train Epoch: 1, Loss: 0.409378, Learning rate: 0.005
# Spended time for 10 batches (total: 3409)(320 images: 1.982655 sec
# Train Epoch: 1, Loss: 0.356342, Learning rate: 0.005
# Spended time for 10 batches (total: 3419)(320 images: 1.839594 sec
# Train Epoch: 1, Loss: 0.374769, Learning rate: 0.005
# Spended time for 10 batches (total: 3429)(320 images: 1.801538 sec
# Train Epoch: 1, Loss: 0.403680, Learning rate: 0.005
# Spended time for 10 batches (total: 3439)(320 images: 1.874438 sec
# Train Epoch: 1, Loss: 0.358211, Learning rate: 0.005
# Spended time for 10 batches (total: 3449)(320 images: 1.857922 sec
# Train Epoch: 1, Loss: 0.346721, Learning rate: 0.005
# Spended time for 10 batches (total: 3459)(320 images: 1.892257 sec
# Train Epoch: 1, Loss: 0.433692, Learning rate: 0.005
# Spended time for 10 batches (total: 3469)(320 images: 1.897947 sec
# Train Epoch: 1, Loss: 0.363499, Learning rate: 0.005
# Spended time for 10 batches (total: 3479)(320 images: 1.969230 sec
# Train Epoch: 1, Loss: 0.358357, Learning rate: 0.005
# Spended time for 10 batches (total: 3489)(320 images: 1.807570 sec
# Train Epoch: 1, Loss: 0.387506, Learning rate: 0.005
# Spended time for 10 batches (total: 3499)(320 images: 1.790839 sec
# Train Epoch: 1, Loss: 0.395378, Learning rate: 0.005
# Spended time for 10 batches (total: 3509)(320 images: 1.878477 sec
# Train Epoch: 1, Loss: 0.369706, Learning rate: 0.005
# Spended time for 10 batches (total: 3519)(320 images: 1.929648 sec
# Train Epoch: 1, Loss: 0.365234, Learning rate: 0.005
# Spended time for 10 batches (total: 3529)(320 images: 1.994605 sec
# Train Epoch: 1, Loss: 0.395665, Learning rate: 0.005
# Spended time for 10 batches (total: 3539)(320 images: 2.083687 sec
# Train Epoch: 1, Loss: 0.306198, Learning rate: 0.005
# Spended time for 10 batches (total: 3549)(320 images: 1.869731 sec
# Train Epoch: 1, Loss: 0.438490, Learning rate: 0.005
# Spended time for 10 batches (total: 3559)(320 images: 1.726481 sec
# Train Epoch: 1, Loss: 0.413672, Learning rate: 0.005
# Spended time for 10 batches (total: 3569)(320 images: 1.835126 sec
# Train Epoch: 1, Loss: 0.419209, Learning rate: 0.005
# Spended time for 10 batches (total: 3579)(320 images: 1.714029 sec
# Train Epoch: 1, Loss: 0.386365, Learning rate: 0.005
# Spended time for 10 batches (total: 3589)(320 images: 1.746007 sec
# Train Epoch: 1, Loss: 0.399878, Learning rate: 0.005
# Spended time for 10 batches (total: 3599)(320 images: 1.693795 sec
# Train Epoch: 1, Loss: 0.353721, Learning rate: 0.005
# Spended time for 10 batches (total: 3609)(320 images: 1.757475 sec
# Train Epoch: 1, Loss: 0.378182, Learning rate: 0.005
# Spended time for 10 batches (total: 3619)(320 images: 1.768929 sec
# Train Epoch: 1, Loss: 0.367774, Learning rate: 0.005
# Spended time for 10 batches (total: 3629)(320 images: 1.756632 sec
# Train Epoch: 1, Loss: 0.388546, Learning rate: 0.005
# Spended time for 10 batches (total: 3639)(320 images: 1.830341 sec
# Train Epoch: 1, Loss: 0.379940, Learning rate: 0.005
# Spended time for 10 batches (total: 3649)(320 images: 1.736578 sec
# Train Epoch: 1, Loss: 0.369759, Learning rate: 0.005
# Spended time for 10 batches (total: 3659)(320 images: 2.126517 sec
# Train Epoch: 1, Loss: 0.372382, Learning rate: 0.005
# Spended time for 10 batches (total: 3669)(320 images: 2.272259 sec
# Train Epoch: 1, Loss: 0.432846, Learning rate: 0.005
# Spended time for 10 batches (total: 3679)(320 images: 1.846084 sec
# Train Epoch: 1, Loss: 0.337592, Learning rate: 0.005
# Spended time for 10 batches (total: 3689)(320 images: 1.821607 sec
# Train Epoch: 1, Loss: 0.432843, Learning rate: 0.005
# Spended time for 10 batches (total: 3699)(320 images: 1.734960 sec
# Train Epoch: 1, Loss: 0.381851, Learning rate: 0.005
# Spended time for 10 batches (total: 3709)(320 images: 2.037934 sec
# Train Epoch: 1, Loss: 0.439992, Learning rate: 0.005
# Spended time for 10 batches (total: 3719)(320 images: 1.951405 sec
# Train Epoch: 1, Loss: 0.408600, Learning rate: 0.005
# Spended time for 10 batches (total: 3729)(320 images: 2.771620 sec
# Train Epoch: 1, Loss: 0.345890, Learning rate: 0.005
# Spended time for 10 batches (total: 3739)(320 images: 2.710601 sec
# Train Epoch: 1, Loss: 0.428962, Learning rate: 0.005
# Spended time for 10 batches (total: 3749)(320 images: 2.526430 sec
# Train Epoch: 1, Loss: 0.393511, Learning rate: 0.005
# Spended time for 10 batches (total: 3759)(320 images: 2.324360 sec
# Train Epoch: 1, Loss: 0.389557, Learning rate: 0.005
# Spended time for 10 batches (total: 3769)(320 images: 3.098058 sec
# Train Epoch: 1, Loss: 0.355610, Learning rate: 0.005
# Spended time for 10 batches (total: 3779)(320 images: 1.918494 sec
# Train Epoch: 1, Loss: 0.335843, Learning rate: 0.005
# Spended time for 10 batches (total: 3789)(320 images: 1.843555 sec
# Train Epoch: 1, Loss: 0.405969, Learning rate: 0.005
# Spended time for 10 batches (total: 3799)(320 images: 1.838244 sec
# Train Epoch: 1, Loss: 0.368522, Learning rate: 0.005
# Spended time for 10 batches (total: 3809)(320 images: 1.920397 sec
# Train Epoch: 1, Loss: 0.431687, Learning rate: 0.005
# Spended time for 10 batches (total: 3819)(320 images: 2.018271 sec
# Train Epoch: 1, Loss: 0.332803, Learning rate: 0.005
# Spended time for 10 batches (total: 3829)(320 images: 2.213483 sec
# Train Epoch: 1, Loss: 0.369094, Learning rate: 0.005
# Spended time for 10 batches (total: 3839)(320 images: 2.106312 sec
# Train Epoch: 1, Loss: 0.458516, Learning rate: 0.005
# Spended time for 10 batches (total: 3849)(320 images: 2.395740 sec
# Train Epoch: 1, Loss: 0.403468, Learning rate: 0.005
# Spended time for 10 batches (total: 3859)(320 images: 1.904459 sec
# Train Epoch: 1, Loss: 0.352198, Learning rate: 0.005
# Spended time for 10 batches (total: 3869)(320 images: 2.018450 sec
# Train Epoch: 1, Loss: 0.409816, Learning rate: 0.005
# Spended time for 10 batches (total: 3879)(320 images: 2.093290 sec
# Train Epoch: 1, Loss: 0.383969, Learning rate: 0.005
# Spended time for 10 batches (total: 3889)(320 images: 1.915563 sec
# Train Epoch: 1, Loss: 0.314059, Learning rate: 0.005
# Spended time for 10 batches (total: 3899)(320 images: 1.910128 sec
# Train Epoch: 1, Loss: 0.371169, Learning rate: 0.005
# Spended time for 10 batches (total: 3909)(320 images: 1.861998 sec
# Train Epoch: 1, Loss: 0.352614, Learning rate: 0.005
# Spended time for 10 batches (total: 3919)(320 images: 1.844679 sec
# Train Epoch: 1, Loss: 0.405910, Learning rate: 0.005
# ...
# Spended time for 10 batches (total: 3879)(320 images: 4.889566 sec
# Train Epoch: 10, Loss: 0.363701, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3889)(320 images: 4.823024 sec
# Train Epoch: 10, Loss: 0.336074, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3899)(320 images: 4.825883 sec
# Train Epoch: 10, Loss: 0.346439, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3909)(320 images: 4.906724 sec
# Train Epoch: 10, Loss: 0.294583, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3919)(320 images: 5.022879 sec
# Train Epoch: 10, Loss: 0.323406, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3929)(320 images: 4.644995 sec
# Train Epoch: 10, Loss: 0.372345, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3939)(320 images: 4.798918 sec
# Train Epoch: 10, Loss: 0.310786, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3949)(320 images: 4.729038 sec
# Train Epoch: 10, Loss: 0.284639, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3959)(320 images: 4.683425 sec
# Train Epoch: 10, Loss: 0.317732, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3969)(320 images: 4.931882 sec
# Train Epoch: 10, Loss: 0.302347, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3979)(320 images: 4.765249 sec
# Train Epoch: 10, Loss: 0.387499, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3989)(320 images: 4.734579 sec
# Train Epoch: 10, Loss: 0.338196, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 3999)(320 images: 4.816865 sec
# Train Epoch: 10, Loss: 0.287349, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4009)(320 images: 4.839162 sec
# Train Epoch: 10, Loss: 0.294442, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4019)(320 images: 4.799222 sec
# Train Epoch: 10, Loss: 0.279814, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4029)(320 images: 4.843931 sec
# Train Epoch: 10, Loss: 0.295344, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4039)(320 images: 4.834280 sec
# Train Epoch: 10, Loss: 0.308046, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4049)(320 images: 4.651769 sec
# Train Epoch: 10, Loss: 0.325966, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4059)(320 images: 4.696397 sec
# Train Epoch: 10, Loss: 0.307657, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4069)(320 images: 4.643789 sec
# Train Epoch: 10, Loss: 0.288544, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4079)(320 images: 4.583762 sec
# Train Epoch: 10, Loss: 0.339027, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4089)(320 images: 4.737288 sec
# Train Epoch: 10, Loss: 0.313883, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4099)(320 images: 4.829832 sec
# Train Epoch: 10, Loss: 0.294983, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4109)(320 images: 4.759584 sec
# Train Epoch: 10, Loss: 0.326412, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4119)(320 images: 4.856946 sec
# Train Epoch: 10, Loss: 0.312204, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4129)(320 images: 4.772302 sec
# Train Epoch: 10, Loss: 0.342599, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4139)(320 images: 4.774530 sec
# Train Epoch: 10, Loss: 0.336720, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4149)(320 images: 4.929102 sec
# Train Epoch: 10, Loss: 0.392908, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4159)(320 images: 4.803617 sec
# Train Epoch: 10, Loss: 0.329381, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4169)(320 images: 4.889087 sec
# Train Epoch: 10, Loss: 0.340504, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4179)(320 images: 4.766052 sec
# Train Epoch: 10, Loss: 0.322710, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4189)(320 images: 4.935190 sec
# Train Epoch: 10, Loss: 0.295845, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4199)(320 images: 4.806303 sec
# Train Epoch: 10, Loss: 0.404642, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4209)(320 images: 4.865043 sec
# Train Epoch: 10, Loss: 0.338624, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4219)(320 images: 4.783762 sec
# Train Epoch: 10, Loss: 0.310790, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4229)(320 images: 4.856815 sec
# Train Epoch: 10, Loss: 0.295698, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4239)(320 images: 4.810775 sec
# Train Epoch: 10, Loss: 0.320593, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4249)(320 images: 4.809821 sec
# Train Epoch: 10, Loss: 0.330603, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4259)(320 images: 4.769909 sec
# Train Epoch: 10, Loss: 0.369533, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4269)(320 images: 4.853140 sec
# Train Epoch: 10, Loss: 0.304408, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4279)(320 images: 4.866556 sec
# Train Epoch: 10, Loss: 0.350187, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4289)(320 images: 4.743178 sec
# Train Epoch: 10, Loss: 0.351938, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4299)(320 images: 4.955205 sec
# Train Epoch: 10, Loss: 0.357409, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4309)(320 images: 4.925967 sec
# Train Epoch: 10, Loss: 0.388043, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4319)(320 images: 4.843117 sec
# Train Epoch: 10, Loss: 0.331891, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4329)(320 images: 4.800446 sec
# Train Epoch: 10, Loss: 0.267500, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4339)(320 images: 4.858619 sec
# Train Epoch: 10, Loss: 0.327679, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4349)(320 images: 4.846164 sec
# Train Epoch: 10, Loss: 0.302765, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4359)(320 images: 4.842313 sec
# Train Epoch: 10, Loss: 0.299562, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4369)(320 images: 4.925331 sec
# Train Epoch: 10, Loss: 0.389709, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4379)(320 images: 4.865848 sec
# Train Epoch: 10, Loss: 0.339284, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4389)(320 images: 4.847241 sec
# Train Epoch: 10, Loss: 0.326426, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4399)(320 images: 4.846830 sec
# Train Epoch: 10, Loss: 0.321899, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4409)(320 images: 4.771535 sec
# Train Epoch: 10, Loss: 0.360580, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4419)(320 images: 5.013138 sec
# Train Epoch: 10, Loss: 0.344694, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4429)(320 images: 4.831020 sec
# Train Epoch: 10, Loss: 0.328047, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4439)(320 images: 4.943402 sec
# Train Epoch: 10, Loss: 0.333815, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4449)(320 images: 5.014908 sec
# Train Epoch: 10, Loss: 0.362683, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4459)(320 images: 4.822611 sec
# Train Epoch: 10, Loss: 0.348895, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4469)(320 images: 4.847457 sec
# Train Epoch: 10, Loss: 0.299846, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4479)(320 images: 4.831063 sec
# Train Epoch: 10, Loss: 0.338603, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4489)(320 images: 4.911028 sec
# Train Epoch: 10, Loss: 0.283170, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4499)(320 images: 4.816059 sec
# Train Epoch: 10, Loss: 0.333209, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4509)(320 images: 4.963107 sec
# Train Epoch: 10, Loss: 0.398395, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4519)(320 images: 5.230576 sec
# Train Epoch: 10, Loss: 0.330815, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4529)(320 images: 5.304326 sec
# Train Epoch: 10, Loss: 0.326411, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4539)(320 images: 5.362138 sec
# Train Epoch: 10, Loss: 0.374852, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4549)(320 images: 5.270518 sec
# Train Epoch: 10, Loss: 0.299624, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4559)(320 images: 5.328231 sec
# Train Epoch: 10, Loss: 0.306748, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4569)(320 images: 5.259280 sec
# Train Epoch: 10, Loss: 0.323072, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4579)(320 images: 4.789826 sec
# Train Epoch: 10, Loss: 0.315599, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4589)(320 images: 4.818683 sec
# Train Epoch: 10, Loss: 0.305278, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4599)(320 images: 4.814482 sec
# Train Epoch: 10, Loss: 0.288425, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4609)(320 images: 5.198997 sec
# Train Epoch: 10, Loss: 0.347414, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4619)(320 images: 5.086677 sec
# Train Epoch: 10, Loss: 0.372985, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4629)(320 images: 4.819331 sec
# Train Epoch: 10, Loss: 0.314406, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4639)(320 images: 4.906848 sec
# Train Epoch: 10, Loss: 0.374901, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4649)(320 images: 4.800622 sec
# Train Epoch: 10, Loss: 0.347283, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4659)(320 images: 4.836958 sec
# Train Epoch: 10, Loss: 0.402349, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4669)(320 images: 4.812301 sec
# Train Epoch: 10, Loss: 0.342369, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4679)(320 images: 4.801083 sec
# Train Epoch: 10, Loss: 0.319863, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4689)(320 images: 4.713495 sec
# Train Epoch: 10, Loss: 0.315001, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4699)(320 images: 4.733499 sec
# Train Epoch: 10, Loss: 0.343677, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4709)(320 images: 4.871374 sec
# Train Epoch: 10, Loss: 0.356237, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4719)(320 images: 4.715045 sec
# Train Epoch: 10, Loss: 0.324574, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4729)(320 images: 4.896723 sec
# Train Epoch: 10, Loss: 0.313379, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4739)(320 images: 4.844412 sec
# Train Epoch: 10, Loss: 0.318192, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4749)(320 images: 4.808394 sec
# Train Epoch: 10, Loss: 0.302057, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4759)(320 images: 4.828282 sec
# Train Epoch: 10, Loss: 0.329402, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4769)(320 images: 4.864503 sec
# Train Epoch: 10, Loss: 0.346363, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4779)(320 images: 4.853067 sec
# Train Epoch: 10, Loss: 0.306688, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4789)(320 images: 4.815635 sec
# Train Epoch: 10, Loss: 0.378287, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4799)(320 images: 4.768143 sec
# Train Epoch: 10, Loss: 0.314604, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4809)(320 images: 4.898567 sec
# Train Epoch: 10, Loss: 0.289871, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4819)(320 images: 4.870457 sec
# Train Epoch: 10, Loss: 0.297798, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4829)(320 images: 4.915832 sec
# Train Epoch: 10, Loss: 0.332199, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4839)(320 images: 4.804073 sec
# Train Epoch: 10, Loss: 0.347390, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4849)(320 images: 4.657591 sec
# Train Epoch: 10, Loss: 0.350771, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4859)(320 images: 4.775385 sec
# Train Epoch: 10, Loss: 0.370208, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4869)(320 images: 4.736232 sec
# Train Epoch: 10, Loss: 0.325818, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4879)(320 images: 4.792582 sec
# Train Epoch: 10, Loss: 0.290966, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4889)(320 images: 4.851986 sec
# Train Epoch: 10, Loss: 0.351524, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4899)(320 images: 4.891848 sec
# Train Epoch: 10, Loss: 0.391407, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4909)(320 images: 4.969156 sec
# Train Epoch: 10, Loss: 0.328418, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4919)(320 images: 4.875341 sec
# Train Epoch: 10, Loss: 0.287006, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4929)(320 images: 4.914456 sec
# Train Epoch: 10, Loss: 0.331119, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4939)(320 images: 4.729066 sec
# Train Epoch: 10, Loss: 0.327566, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4949)(320 images: 4.815718 sec
# Train Epoch: 10, Loss: 0.369568, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4959)(320 images: 4.881874 sec
# Train Epoch: 10, Loss: 0.362033, Learning rate: 0.0031512470486230455
# Spended time for 10 batches (total: 4969)(320 images: 4.705693 sec
# ================================================================================
# Epoch 10, train loss: 0.334388, valid loss: 0.343503, valid metric: 0.923128
# ================================================================================
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:133: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
model_wrapper.save('/Users/igorfrolkin/Downloads/vad_model2_1.pth')

# %% [markdown]
# # После 10 эпох обучения

# %%
result_train
# Out:
# {'epoch_train_losses': [0.41083643706850387,
#   0.36607636864917786,
#   0.3568327997971879,
#   0.3527680746963974,
#   0.34883408695579127,
#   0.34648330359662993,
#   0.34355734193932225,
#   0.34244269511056324,
#   0.339041464253796,
#   0.3343882948857775],
#  'epoch_valid_losses': [0.3669183028568842,
#   0.35143945446982305,
#   0.3557881670608227,
#   0.3908655887863735,
#   0.3514752438389587,
#   0.3479071766892566,
#   0.3587289160592431,
#   0.34907077576217344,
#   0.34683770853453477,
#   0.3435025591585132],
#  'epoch_valid_metrics': [0.9109991516108409,
#   0.9183640009451197,
#   0.9167367080374482,
#   0.9170941038129641,
#   0.9178856436097865,
#   0.9193286276072922,
#   0.9183474056875508,
#   0.9188549943286253,
#   0.920882720132139,
#   0.9231276497057093]}

# %%
result_train_10_epoch = result_train.copy()

# %%
plt.plot(result_train_10_epoch['epoch_train_losses'])
plt.plot(result_train_10_epoch['epoch_valid_losses'])

# %%
plt.plot(result_train_10_epoch['epoch_valid_metrics'])

# %%
y_true, y_proba = test_result(model, test_data_loader)
# Out:
# {'test_loss': 0.3415502811999573, 'test_metric': 0.923768188098981}
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plot_precision_recall(y_true, y_proba)

# %%
show_proba_calibration_plots(y_proba, y_true)

# %%
report(y_true, y_proba, 0.4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85     20455
#            1       0.89      0.83      0.86     23779
#
#     accuracy                           0.86     44234
#    macro avg       0.86      0.86      0.86     44234
# weighted avg       0.86      0.86      0.86     44234
#
# ---------------
# Матрица ошибок:
# [[18040  2415]
#  [ 3968 19811]]
# ---------------
# Правильно предсказано 0: 18040
# Правильно предсказано 1: 19811
# Ложноотрицательных (FN, ош2р, пропуск события): 3968
# Ложноположительных (FP, ош1р, ложная  тревога): 2415
# Всего ошибок: 6383

# %% [markdown]
# # После 15 эпох обучения

# %%
result_train = model_wrapper.fit(criterion,
             metric,
             optimizer,
             scheduler,
             train_data_loader,
             valid_data_loader,
             epochs=3,
             verbose=10)
# Out:
# Train Epoch: 1, Loss: 0.358005, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 9)(320 images: 5.212410 sec
# Train Epoch: 1, Loss: 0.323419, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 19)(320 images: 4.980867 sec
# Train Epoch: 1, Loss: 0.299017, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 29)(320 images: 4.743820 sec
# Train Epoch: 1, Loss: 0.348246, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 39)(320 images: 4.787416 sec
# Train Epoch: 1, Loss: 0.382653, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 49)(320 images: 4.625921 sec
# Train Epoch: 1, Loss: 0.268428, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 59)(320 images: 4.615187 sec
# Train Epoch: 1, Loss: 0.308369, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 69)(320 images: 4.666147 sec
# Train Epoch: 1, Loss: 0.320580, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 79)(320 images: 4.614592 sec
# Train Epoch: 1, Loss: 0.325993, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 89)(320 images: 4.860429 sec
# Train Epoch: 1, Loss: 0.336708, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 99)(320 images: 4.770628 sec
# Train Epoch: 1, Loss: 0.340350, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 109)(320 images: 4.801385 sec
# Train Epoch: 1, Loss: 0.327973, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 119)(320 images: 4.707195 sec
# Train Epoch: 1, Loss: 0.374939, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 129)(320 images: 4.785808 sec
# Train Epoch: 1, Loss: 0.355575, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 139)(320 images: 4.663057 sec
# Train Epoch: 1, Loss: 0.393341, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 149)(320 images: 4.769180 sec
# Train Epoch: 1, Loss: 0.389573, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 159)(320 images: 4.724853 sec
# Train Epoch: 1, Loss: 0.287415, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 169)(320 images: 4.673356 sec
# Train Epoch: 1, Loss: 0.301510, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 179)(320 images: 4.696609 sec
# Train Epoch: 1, Loss: 0.263315, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 189)(320 images: 4.641916 sec
# Train Epoch: 1, Loss: 0.283905, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 199)(320 images: 4.793394 sec
# Train Epoch: 1, Loss: 0.316790, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 209)(320 images: 4.727223 sec
# Train Epoch: 1, Loss: 0.360877, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 219)(320 images: 4.758443 sec
# Train Epoch: 1, Loss: 0.332275, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 229)(320 images: 4.773456 sec
# Train Epoch: 1, Loss: 0.312839, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 239)(320 images: 4.892404 sec
# Train Epoch: 1, Loss: 0.361088, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 249)(320 images: 4.723897 sec
# Train Epoch: 1, Loss: 0.318009, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 259)(320 images: 4.762328 sec
# Train Epoch: 1, Loss: 0.332713, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 269)(320 images: 4.732613 sec
# Train Epoch: 1, Loss: 0.264560, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 279)(320 images: 4.604662 sec
# Train Epoch: 1, Loss: 0.369473, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 289)(320 images: 4.571268 sec
# Train Epoch: 1, Loss: 0.344107, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 299)(320 images: 4.629105 sec
# Train Epoch: 1, Loss: 0.312594, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 309)(320 images: 4.617118 sec
# Train Epoch: 1, Loss: 0.297939, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 319)(320 images: 4.580815 sec
# Train Epoch: 1, Loss: 0.304108, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 329)(320 images: 4.674914 sec
# Train Epoch: 1, Loss: 0.331685, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 339)(320 images: 4.673072 sec
# Train Epoch: 1, Loss: 0.358871, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 349)(320 images: 4.692785 sec
# Train Epoch: 1, Loss: 0.303972, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 359)(320 images: 4.565422 sec
# Train Epoch: 1, Loss: 0.340089, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 369)(320 images: 4.642698 sec
# Train Epoch: 1, Loss: 0.256901, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 379)(320 images: 4.620273 sec
# Train Epoch: 1, Loss: 0.338787, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 389)(320 images: 4.596601 sec
# Train Epoch: 1, Loss: 0.298149, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 399)(320 images: 4.635031 sec
# Train Epoch: 1, Loss: 0.300045, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 409)(320 images: 4.665313 sec
# Train Epoch: 1, Loss: 0.346027, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 419)(320 images: 4.684520 sec
# Train Epoch: 1, Loss: 0.305353, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 429)(320 images: 4.676167 sec
# Train Epoch: 1, Loss: 0.323988, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 439)(320 images: 4.535172 sec
# Train Epoch: 1, Loss: 0.301340, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 449)(320 images: 4.595155 sec
# Train Epoch: 1, Loss: 0.329668, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 459)(320 images: 4.594870 sec
# Train Epoch: 1, Loss: 0.285174, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 469)(320 images: 4.577141 sec
# Train Epoch: 1, Loss: 0.289243, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 479)(320 images: 4.573385 sec
# Train Epoch: 1, Loss: 0.309515, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 489)(320 images: 4.559433 sec
# Train Epoch: 1, Loss: 0.314958, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 499)(320 images: 4.716986 sec
# Train Epoch: 1, Loss: 0.383826, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 509)(320 images: 4.583786 sec
# Train Epoch: 1, Loss: 0.364123, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 519)(320 images: 4.639415 sec
# Train Epoch: 1, Loss: 0.326854, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 529)(320 images: 4.600844 sec
# Train Epoch: 1, Loss: 0.300532, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 539)(320 images: 4.535369 sec
# Train Epoch: 1, Loss: 0.334998, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 549)(320 images: 4.476511 sec
# Train Epoch: 1, Loss: 0.364094, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 559)(320 images: 4.635094 sec
# Train Epoch: 1, Loss: 0.307635, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 569)(320 images: 4.577772 sec
# Train Epoch: 1, Loss: 0.347281, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 579)(320 images: 4.647984 sec
# Train Epoch: 1, Loss: 0.321006, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 589)(320 images: 4.557295 sec
# Train Epoch: 1, Loss: 0.360607, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 599)(320 images: 4.494188 sec
# Train Epoch: 1, Loss: 0.319469, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 609)(320 images: 4.525388 sec
# Train Epoch: 1, Loss: 0.334224, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 619)(320 images: 4.485076 sec
# Train Epoch: 1, Loss: 0.279212, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 629)(320 images: 4.608495 sec
# Train Epoch: 1, Loss: 0.308513, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 639)(320 images: 4.551252 sec
# Train Epoch: 1, Loss: 0.348786, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 649)(320 images: 4.578440 sec
# Train Epoch: 1, Loss: 0.327592, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 659)(320 images: 4.830560 sec
# Train Epoch: 1, Loss: 0.263951, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 669)(320 images: 4.904308 sec
# Train Epoch: 1, Loss: 0.385615, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 679)(320 images: 4.904131 sec
# Train Epoch: 1, Loss: 0.310597, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 689)(320 images: 4.797868 sec
# Train Epoch: 1, Loss: 0.297473, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 699)(320 images: 5.071949 sec
# Train Epoch: 1, Loss: 0.363692, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 709)(320 images: 4.887356 sec
# Train Epoch: 1, Loss: 0.311286, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 719)(320 images: 4.942640 sec
# Train Epoch: 1, Loss: 0.299602, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 729)(320 images: 4.797886 sec
# Train Epoch: 1, Loss: 0.343179, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 739)(320 images: 4.623301 sec
# Train Epoch: 1, Loss: 0.268374, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 749)(320 images: 4.496431 sec
# Train Epoch: 1, Loss: 0.320519, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 759)(320 images: 4.519086 sec
# Train Epoch: 1, Loss: 0.301348, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 769)(320 images: 4.581716 sec
# Train Epoch: 1, Loss: 0.300442, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 779)(320 images: 4.366256 sec
# Train Epoch: 1, Loss: 0.292909, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 789)(320 images: 4.363242 sec
# Train Epoch: 1, Loss: 0.331861, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 799)(320 images: 4.209127 sec
# Train Epoch: 1, Loss: 0.350098, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 809)(320 images: 4.281943 sec
# Train Epoch: 1, Loss: 0.317794, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 819)(320 images: 4.440827 sec
# Train Epoch: 1, Loss: 0.385059, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 829)(320 images: 4.547245 sec
# Train Epoch: 1, Loss: 0.383531, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 839)(320 images: 4.554891 sec
# Train Epoch: 1, Loss: 0.284611, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 849)(320 images: 4.597040 sec
# Train Epoch: 1, Loss: 0.343082, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 859)(320 images: 4.574581 sec
# Train Epoch: 1, Loss: 0.354491, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 869)(320 images: 4.699693 sec
# Train Epoch: 1, Loss: 0.337061, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 879)(320 images: 4.521889 sec
# Train Epoch: 1, Loss: 0.314463, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 889)(320 images: 4.561612 sec
# Train Epoch: 1, Loss: 0.339526, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 899)(320 images: 4.449074 sec
# Train Epoch: 1, Loss: 0.329866, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 909)(320 images: 4.514783 sec
# Train Epoch: 1, Loss: 0.322492, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 919)(320 images: 4.533245 sec
# Train Epoch: 1, Loss: 0.298621, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 929)(320 images: 4.391225 sec
# Train Epoch: 1, Loss: 0.287775, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 939)(320 images: 4.452375 sec
# Train Epoch: 1, Loss: 0.326101, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 949)(320 images: 4.448637 sec
# Train Epoch: 1, Loss: 0.285006, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 959)(320 images: 4.491308 sec
# Train Epoch: 1, Loss: 0.330254, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 969)(320 images: 4.463211 sec
# Train Epoch: 1, Loss: 0.336575, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 979)(320 images: 4.534007 sec
# Train Epoch: 1, Loss: 0.335413, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 989)(320 images: 4.464949 sec
# Train Epoch: 1, Loss: 0.334234, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 999)(320 images: 4.515242 sec
# Train Epoch: 1, Loss: 0.302548, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1009)(320 images: 4.407636 sec
# Train Epoch: 1, Loss: 0.300487, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1019)(320 images: 4.341513 sec
# Train Epoch: 1, Loss: 0.286179, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1029)(320 images: 4.375048 sec
# Train Epoch: 1, Loss: 0.454284, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1039)(320 images: 4.454090 sec
# Train Epoch: 1, Loss: 0.304612, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1049)(320 images: 4.418244 sec
# Train Epoch: 1, Loss: 0.393005, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1059)(320 images: 4.566091 sec
# Train Epoch: 1, Loss: 0.317729, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1069)(320 images: 4.453065 sec
# Train Epoch: 1, Loss: 0.325573, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1079)(320 images: 4.497252 sec
# Train Epoch: 1, Loss: 0.264041, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1089)(320 images: 4.380065 sec
# Train Epoch: 1, Loss: 0.331964, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1099)(320 images: 4.453572 sec
# Train Epoch: 1, Loss: 0.331256, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1109)(320 images: 4.493416 sec
# Train Epoch: 1, Loss: 0.291631, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1119)(320 images: 4.474761 sec
# Train Epoch: 1, Loss: 0.328830, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1129)(320 images: 4.582140 sec
# Train Epoch: 1, Loss: 0.331558, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1139)(320 images: 4.497487 sec
# Train Epoch: 1, Loss: 0.333563, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1149)(320 images: 4.558103 sec
# Train Epoch: 1, Loss: 0.349453, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1159)(320 images: 4.536907 sec
# Train Epoch: 1, Loss: 0.273898, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1169)(320 images: 4.554902 sec
# Train Epoch: 1, Loss: 0.340955, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1179)(320 images: 4.453378 sec
# Train Epoch: 1, Loss: 0.374734, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1189)(320 images: 4.561502 sec
# Train Epoch: 1, Loss: 0.407773, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1199)(320 images: 4.519231 sec
# Train Epoch: 1, Loss: 0.351058, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1209)(320 images: 4.562253 sec
# Train Epoch: 1, Loss: 0.330919, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1219)(320 images: 4.449111 sec
# Train Epoch: 1, Loss: 0.383103, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1229)(320 images: 4.438513 sec
# Train Epoch: 1, Loss: 0.309679, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1239)(320 images: 4.518168 sec
# Train Epoch: 1, Loss: 0.321736, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1249)(320 images: 4.940754 sec
# Train Epoch: 1, Loss: 0.322949, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1259)(320 images: 4.492988 sec
# Train Epoch: 1, Loss: 0.300450, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1269)(320 images: 4.919021 sec
# Train Epoch: 1, Loss: 0.296203, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1279)(320 images: 4.898258 sec
# Train Epoch: 1, Loss: 0.318385, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1289)(320 images: 4.581001 sec
# Train Epoch: 1, Loss: 0.328000, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1299)(320 images: 4.493182 sec
# Train Epoch: 1, Loss: 0.312491, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1309)(320 images: 4.545103 sec
# Train Epoch: 1, Loss: 0.359432, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1319)(320 images: 4.631050 sec
# Train Epoch: 1, Loss: 0.315155, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1329)(320 images: 4.457713 sec
# Train Epoch: 1, Loss: 0.285615, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1339)(320 images: 4.503029 sec
# Train Epoch: 1, Loss: 0.391341, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1349)(320 images: 4.531550 sec
# Train Epoch: 1, Loss: 0.338424, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1359)(320 images: 4.577485 sec
# Train Epoch: 1, Loss: 0.306462, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1369)(320 images: 4.447136 sec
# Train Epoch: 1, Loss: 0.318393, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1379)(320 images: 4.384847 sec
# Train Epoch: 1, Loss: 0.287743, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1389)(320 images: 4.567483 sec
# Train Epoch: 1, Loss: 0.315287, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1399)(320 images: 4.502251 sec
# Train Epoch: 1, Loss: 0.302585, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1409)(320 images: 4.380174 sec
# Train Epoch: 1, Loss: 0.336107, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1419)(320 images: 4.447290 sec
# Train Epoch: 1, Loss: 0.302965, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1429)(320 images: 4.405544 sec
# Train Epoch: 1, Loss: 0.363837, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1439)(320 images: 4.339334 sec
# Train Epoch: 1, Loss: 0.393839, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1449)(320 images: 4.427476 sec
# Train Epoch: 1, Loss: 0.355265, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1459)(320 images: 4.383754 sec
# Train Epoch: 1, Loss: 0.357522, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1469)(320 images: 4.432166 sec
# Train Epoch: 1, Loss: 0.345869, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1479)(320 images: 4.426267 sec
# Train Epoch: 1, Loss: 0.361601, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1489)(320 images: 4.426439 sec
# Train Epoch: 1, Loss: 0.347213, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1499)(320 images: 4.480581 sec
# Train Epoch: 1, Loss: 0.301884, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1509)(320 images: 4.464760 sec
# Train Epoch: 1, Loss: 0.328861, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1519)(320 images: 4.571502 sec
# Train Epoch: 1, Loss: 0.307421, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1529)(320 images: 4.628265 sec
# Train Epoch: 1, Loss: 0.305759, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1539)(320 images: 4.759741 sec
# Train Epoch: 1, Loss: 0.347652, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1549)(320 images: 5.054502 sec
# Train Epoch: 1, Loss: 0.343508, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1559)(320 images: 4.648403 sec
# Train Epoch: 1, Loss: 0.348136, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1569)(320 images: 4.632214 sec
# Train Epoch: 1, Loss: 0.291171, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1579)(320 images: 5.143270 sec
# Train Epoch: 1, Loss: 0.337253, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1589)(320 images: 4.815355 sec
# Train Epoch: 1, Loss: 0.366244, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1599)(320 images: 4.779567 sec
# Train Epoch: 1, Loss: 0.289543, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1609)(320 images: 4.670499 sec
# Train Epoch: 1, Loss: 0.327122, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1619)(320 images: 4.422269 sec
# Train Epoch: 1, Loss: 0.342614, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1629)(320 images: 4.492361 sec
# Train Epoch: 1, Loss: 0.330909, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1639)(320 images: 4.459016 sec
# Train Epoch: 1, Loss: 0.286409, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1649)(320 images: 4.540120 sec
# Train Epoch: 1, Loss: 0.333387, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1659)(320 images: 4.433272 sec
# Train Epoch: 1, Loss: 0.347650, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1669)(320 images: 4.492011 sec
# Train Epoch: 1, Loss: 0.313305, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1679)(320 images: 4.570247 sec
# Train Epoch: 1, Loss: 0.324813, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1689)(320 images: 4.614727 sec
# Train Epoch: 1, Loss: 0.304639, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1699)(320 images: 4.595918 sec
# Train Epoch: 1, Loss: 0.342719, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1709)(320 images: 4.689171 sec
# Train Epoch: 1, Loss: 0.309602, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1719)(320 images: 4.528607 sec
# Train Epoch: 1, Loss: 0.291250, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1729)(320 images: 4.449133 sec
# Train Epoch: 1, Loss: 0.313664, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1739)(320 images: 4.481313 sec
# Train Epoch: 1, Loss: 0.352664, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1749)(320 images: 4.509606 sec
# Train Epoch: 1, Loss: 0.354488, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1759)(320 images: 4.617913 sec
# Train Epoch: 1, Loss: 0.303906, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1769)(320 images: 4.648902 sec
# Train Epoch: 1, Loss: 0.393897, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1779)(320 images: 4.549830 sec
# Train Epoch: 1, Loss: 0.313371, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1789)(320 images: 4.590291 sec
# Train Epoch: 1, Loss: 0.396001, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1799)(320 images: 4.573514 sec
# Train Epoch: 1, Loss: 0.304527, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1809)(320 images: 4.529641 sec
# Train Epoch: 1, Loss: 0.304124, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1819)(320 images: 4.473840 sec
# Train Epoch: 1, Loss: 0.409973, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1829)(320 images: 4.551030 sec
# Train Epoch: 1, Loss: 0.300961, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1839)(320 images: 4.445070 sec
# Train Epoch: 1, Loss: 0.310194, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1849)(320 images: 4.665301 sec
# Train Epoch: 1, Loss: 0.319089, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1859)(320 images: 4.545981 sec
# Train Epoch: 1, Loss: 0.310209, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1869)(320 images: 4.461972 sec
# Train Epoch: 1, Loss: 0.331218, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1879)(320 images: 4.457149 sec
# Train Epoch: 1, Loss: 0.257272, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1889)(320 images: 4.382247 sec
# Train Epoch: 1, Loss: 0.333203, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1899)(320 images: 4.422805 sec
# Train Epoch: 1, Loss: 0.335925, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1909)(320 images: 4.546878 sec
# Train Epoch: 1, Loss: 0.364873, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1919)(320 images: 4.711561 sec
# Train Epoch: 1, Loss: 0.317563, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1929)(320 images: 4.713111 sec
# Train Epoch: 1, Loss: 0.355989, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1939)(320 images: 5.011115 sec
# Train Epoch: 1, Loss: 0.299346, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1949)(320 images: 4.574049 sec
# Train Epoch: 1, Loss: 0.330442, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1959)(320 images: 4.567845 sec
# Train Epoch: 1, Loss: 0.312538, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1969)(320 images: 4.682193 sec
# Train Epoch: 1, Loss: 0.319873, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1979)(320 images: 4.552173 sec
# Train Epoch: 1, Loss: 0.297528, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1989)(320 images: 4.434035 sec
# Train Epoch: 1, Loss: 0.308447, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 1999)(320 images: 4.440727 sec
# Train Epoch: 1, Loss: 0.361954, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2009)(320 images: 4.423990 sec
# Train Epoch: 1, Loss: 0.331428, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2019)(320 images: 4.505263 sec
# Train Epoch: 1, Loss: 0.296940, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2029)(320 images: 4.573390 sec
# Train Epoch: 1, Loss: 0.387960, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2039)(320 images: 4.522635 sec
# Train Epoch: 1, Loss: 0.347546, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2049)(320 images: 4.570600 sec
# Train Epoch: 1, Loss: 0.312376, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2059)(320 images: 4.557274 sec
# Train Epoch: 1, Loss: 0.301125, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2069)(320 images: 4.484886 sec
# Train Epoch: 1, Loss: 0.306497, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2079)(320 images: 4.507145 sec
# Train Epoch: 1, Loss: 0.312202, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2089)(320 images: 4.515266 sec
# Train Epoch: 1, Loss: 0.357953, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2099)(320 images: 4.752095 sec
# Train Epoch: 1, Loss: 0.302556, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2109)(320 images: 4.721288 sec
# Train Epoch: 1, Loss: 0.343482, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2119)(320 images: 4.462388 sec
# Train Epoch: 1, Loss: 0.356799, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2129)(320 images: 4.263071 sec
# Train Epoch: 1, Loss: 0.323688, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2139)(320 images: 4.494448 sec
# Train Epoch: 1, Loss: 0.327293, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2149)(320 images: 4.585475 sec
# Train Epoch: 1, Loss: 0.298815, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2159)(320 images: 4.539333 sec
# Train Epoch: 1, Loss: 0.312737, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2169)(320 images: 4.629555 sec
# Train Epoch: 1, Loss: 0.362894, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2179)(320 images: 4.689990 sec
# Train Epoch: 1, Loss: 0.305999, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2189)(320 images: 4.823855 sec
# Train Epoch: 1, Loss: 0.343196, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2199)(320 images: 4.803040 sec
# Train Epoch: 1, Loss: 0.328904, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2209)(320 images: 4.520762 sec
# Train Epoch: 1, Loss: 0.315001, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2219)(320 images: 4.617857 sec
# Train Epoch: 1, Loss: 0.349612, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2229)(320 images: 4.834732 sec
# Train Epoch: 1, Loss: 0.296348, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2239)(320 images: 4.727632 sec
# Train Epoch: 1, Loss: 0.294489, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2249)(320 images: 4.799380 sec
# Train Epoch: 1, Loss: 0.259271, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2259)(320 images: 4.725494 sec
# Train Epoch: 1, Loss: 0.340816, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2269)(320 images: 4.843666 sec
# Train Epoch: 1, Loss: 0.303823, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2279)(320 images: 4.645374 sec
# Train Epoch: 1, Loss: 0.322620, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2289)(320 images: 4.688620 sec
# Train Epoch: 1, Loss: 0.311148, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2299)(320 images: 4.678741 sec
# Train Epoch: 1, Loss: 0.265219, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2309)(320 images: 4.799133 sec
# Train Epoch: 1, Loss: 0.313288, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2319)(320 images: 4.854909 sec
# Train Epoch: 1, Loss: 0.319945, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2329)(320 images: 4.852052 sec
# Train Epoch: 1, Loss: 0.307713, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2339)(320 images: 5.098717 sec
# Train Epoch: 1, Loss: 0.336145, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2349)(320 images: 5.027224 sec
# Train Epoch: 1, Loss: 0.335678, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2359)(320 images: 4.810651 sec
# Train Epoch: 1, Loss: 0.340423, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2369)(320 images: 4.795865 sec
# Train Epoch: 1, Loss: 0.286921, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2379)(320 images: 4.937978 sec
# Train Epoch: 1, Loss: 0.338677, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2389)(320 images: 4.829353 sec
# Train Epoch: 1, Loss: 0.337922, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2399)(320 images: 4.473082 sec
# Train Epoch: 1, Loss: 0.372700, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2409)(320 images: 4.385512 sec
# Train Epoch: 1, Loss: 0.325991, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2419)(320 images: 4.626852 sec
# Train Epoch: 1, Loss: 0.302441, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2429)(320 images: 4.682117 sec
# Train Epoch: 1, Loss: 0.331056, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2439)(320 images: 4.685663 sec
# Train Epoch: 1, Loss: 0.297389, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2449)(320 images: 4.505911 sec
# Train Epoch: 1, Loss: 0.367107, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2459)(320 images: 4.625695 sec
# Train Epoch: 1, Loss: 0.349532, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2469)(320 images: 4.552417 sec
# Train Epoch: 1, Loss: 0.345172, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2479)(320 images: 4.611787 sec
# Train Epoch: 1, Loss: 0.307089, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2489)(320 images: 4.410121 sec
# Train Epoch: 1, Loss: 0.307279, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2499)(320 images: 4.532603 sec
# Train Epoch: 1, Loss: 0.351208, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2509)(320 images: 4.566937 sec
# Train Epoch: 1, Loss: 0.309294, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2519)(320 images: 4.620927 sec
# Train Epoch: 1, Loss: 0.311681, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2529)(320 images: 4.558587 sec
# Train Epoch: 1, Loss: 0.327442, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2539)(320 images: 4.593195 sec
# Train Epoch: 1, Loss: 0.298399, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2549)(320 images: 4.547586 sec
# Train Epoch: 1, Loss: 0.270665, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2559)(320 images: 4.517904 sec
# Train Epoch: 1, Loss: 0.294340, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2569)(320 images: 4.514025 sec
# Train Epoch: 1, Loss: 0.317796, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2579)(320 images: 4.585322 sec
# Train Epoch: 1, Loss: 0.309868, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2589)(320 images: 4.548688 sec
# Train Epoch: 1, Loss: 0.337600, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2599)(320 images: 4.546669 sec
# Train Epoch: 1, Loss: 0.338107, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2609)(320 images: 5.438239 sec
# Train Epoch: 1, Loss: 0.384024, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2619)(320 images: 5.739024 sec
# Train Epoch: 1, Loss: 0.346181, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2629)(320 images: 5.813638 sec
# Train Epoch: 1, Loss: 0.361538, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2639)(320 images: 5.975791 sec
# Train Epoch: 1, Loss: 0.314750, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2649)(320 images: 5.950388 sec
# Train Epoch: 1, Loss: 0.324936, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2659)(320 images: 5.885032 sec
# Train Epoch: 1, Loss: 0.286902, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2669)(320 images: 6.149116 sec
# Train Epoch: 1, Loss: 0.303795, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2679)(320 images: 6.210375 sec
# Train Epoch: 1, Loss: 0.268759, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2689)(320 images: 6.029759 sec
# Train Epoch: 1, Loss: 0.310150, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2699)(320 images: 5.798031 sec
# Train Epoch: 1, Loss: 0.263546, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2709)(320 images: 5.513246 sec
# Train Epoch: 1, Loss: 0.311043, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2719)(320 images: 5.932108 sec
# Train Epoch: 1, Loss: 0.381896, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2729)(320 images: 5.759304 sec
# Train Epoch: 1, Loss: 0.372368, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2739)(320 images: 5.776206 sec
# Train Epoch: 1, Loss: 0.273737, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2749)(320 images: 5.632402 sec
# Train Epoch: 1, Loss: 0.386250, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2759)(320 images: 5.619272 sec
# Train Epoch: 1, Loss: 0.348516, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2769)(320 images: 5.700597 sec
# Train Epoch: 1, Loss: 0.341946, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2779)(320 images: 5.892037 sec
# Train Epoch: 1, Loss: 0.319642, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2789)(320 images: 5.619792 sec
# Train Epoch: 1, Loss: 0.287789, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2799)(320 images: 5.466817 sec
# Train Epoch: 1, Loss: 0.374888, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2809)(320 images: 5.455451 sec
# Train Epoch: 1, Loss: 0.346059, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2819)(320 images: 5.544668 sec
# Train Epoch: 1, Loss: 0.312300, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2829)(320 images: 5.489438 sec
# Train Epoch: 1, Loss: 0.291225, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2839)(320 images: 5.430781 sec
# Train Epoch: 1, Loss: 0.279285, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2849)(320 images: 5.457714 sec
# Train Epoch: 1, Loss: 0.338852, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2859)(320 images: 5.536652 sec
# Train Epoch: 1, Loss: 0.313551, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2869)(320 images: 5.517435 sec
# Train Epoch: 1, Loss: 0.318925, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2879)(320 images: 5.713283 sec
# Train Epoch: 1, Loss: 0.313406, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2889)(320 images: 5.522143 sec
# Train Epoch: 1, Loss: 0.308295, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2899)(320 images: 5.533210 sec
# Train Epoch: 1, Loss: 0.304143, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2909)(320 images: 5.534988 sec
# Train Epoch: 1, Loss: 0.348488, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2919)(320 images: 5.482012 sec
# Train Epoch: 1, Loss: 0.278620, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2929)(320 images: 5.523033 sec
# Train Epoch: 1, Loss: 0.354723, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2939)(320 images: 5.368577 sec
# Train Epoch: 1, Loss: 0.331303, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2949)(320 images: 5.584107 sec
# Train Epoch: 1, Loss: 0.308309, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2959)(320 images: 5.475554 sec
# Train Epoch: 1, Loss: 0.371659, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2969)(320 images: 5.489727 sec
# Train Epoch: 1, Loss: 0.392463, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2979)(320 images: 5.463334 sec
# Train Epoch: 1, Loss: 0.345151, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2989)(320 images: 5.727251 sec
# Train Epoch: 1, Loss: 0.352954, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 2999)(320 images: 5.530220 sec
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:133: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ================================================================================
# Epoch 1, train loss: 0.325950, valid loss: 0.340732, valid metric: 0.922878
# ================================================================================
# Train Epoch: 1, Loss: 0.324185, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3009)(320 images: 82.921270 sec
# Train Epoch: 1, Loss: 0.337373, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3019)(320 images: 5.556053 sec
# Train Epoch: 1, Loss: 0.344017, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3029)(320 images: 5.606222 sec
# Train Epoch: 1, Loss: 0.335886, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3039)(320 images: 5.624943 sec
# Train Epoch: 1, Loss: 0.393422, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3049)(320 images: 5.490552 sec
# Train Epoch: 1, Loss: 0.332780, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3059)(320 images: 5.310569 sec
# Train Epoch: 1, Loss: 0.392733, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3069)(320 images: 5.464003 sec
# Train Epoch: 1, Loss: 0.359930, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3079)(320 images: 5.515791 sec
# Train Epoch: 1, Loss: 0.337087, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3089)(320 images: 5.538486 sec
# Train Epoch: 1, Loss: 0.354843, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3099)(320 images: 5.460858 sec
# Train Epoch: 1, Loss: 0.266320, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3109)(320 images: 5.399337 sec
# Train Epoch: 1, Loss: 0.306319, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3119)(320 images: 5.427319 sec
# Train Epoch: 1, Loss: 0.307748, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3129)(320 images: 5.595877 sec
# Train Epoch: 1, Loss: 0.295668, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3139)(320 images: 5.442658 sec
# Train Epoch: 1, Loss: 0.295198, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3149)(320 images: 5.503429 sec
# Train Epoch: 1, Loss: 0.298799, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3159)(320 images: 5.706300 sec
# Train Epoch: 1, Loss: 0.283465, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3169)(320 images: 5.655171 sec
# Train Epoch: 1, Loss: 0.337219, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3179)(320 images: 5.659099 sec
# Train Epoch: 1, Loss: 0.342958, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3189)(320 images: 5.717763 sec
# Train Epoch: 1, Loss: 0.339524, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3199)(320 images: 5.670319 sec
# Train Epoch: 1, Loss: 0.371682, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3209)(320 images: 5.732611 sec
# Train Epoch: 1, Loss: 0.269941, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3219)(320 images: 5.674631 sec
# Train Epoch: 1, Loss: 0.335055, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3229)(320 images: 5.648643 sec
# Train Epoch: 1, Loss: 0.355015, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3239)(320 images: 5.949677 sec
# Train Epoch: 1, Loss: 0.295570, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3249)(320 images: 5.796579 sec
# Train Epoch: 1, Loss: 0.322784, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3259)(320 images: 5.720635 sec
# Train Epoch: 1, Loss: 0.308946, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3269)(320 images: 5.933212 sec
# Train Epoch: 1, Loss: 0.341189, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3279)(320 images: 5.931194 sec
# Train Epoch: 1, Loss: 0.318103, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3289)(320 images: 5.686732 sec
# Train Epoch: 1, Loss: 0.340764, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3299)(320 images: 6.096735 sec
# Train Epoch: 1, Loss: 0.338903, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3309)(320 images: 5.649912 sec
# Train Epoch: 1, Loss: 0.336808, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3319)(320 images: 5.640078 sec
# Train Epoch: 1, Loss: 0.373560, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3329)(320 images: 5.556219 sec
# Train Epoch: 1, Loss: 0.358534, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3339)(320 images: 5.401280 sec
# Train Epoch: 1, Loss: 0.305973, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3349)(320 images: 5.364067 sec
# Train Epoch: 1, Loss: 0.335377, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3359)(320 images: 5.627955 sec
# Train Epoch: 1, Loss: 0.299115, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3369)(320 images: 5.597634 sec
# Train Epoch: 1, Loss: 0.306065, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3379)(320 images: 5.519428 sec
# Train Epoch: 1, Loss: 0.388711, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3389)(320 images: 5.548410 sec
# Train Epoch: 1, Loss: 0.370795, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3399)(320 images: 5.508767 sec
# Train Epoch: 1, Loss: 0.380838, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3409)(320 images: 5.521237 sec
# Train Epoch: 1, Loss: 0.327954, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3419)(320 images: 5.411700 sec
# Train Epoch: 1, Loss: 0.276848, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3429)(320 images: 5.410769 sec
# Train Epoch: 1, Loss: 0.250802, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3439)(320 images: 5.532459 sec
# Train Epoch: 1, Loss: 0.338254, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3449)(320 images: 5.477799 sec
# Train Epoch: 1, Loss: 0.324619, Learning rate: 0.0027018004383131834
# Spended time for 10 batches (total: 3459)(320 images: 5.465492 sec
# Train Epoch: 1, Loss: 0.292472, Learning rate: 0.0027018004383131834
# ...
# Train Epoch: 3, Loss: 0.350895, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3879)(320 images: 4.325939 sec
# Train Epoch: 3, Loss: 0.355608, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3889)(320 images: 4.346359 sec
# Train Epoch: 3, Loss: 0.339313, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3899)(320 images: 4.327560 sec
# Train Epoch: 3, Loss: 0.363461, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3909)(320 images: 4.362925 sec
# Train Epoch: 3, Loss: 0.341089, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3919)(320 images: 4.335339 sec
# Train Epoch: 3, Loss: 0.323511, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3929)(320 images: 4.296415 sec
# Train Epoch: 3, Loss: 0.276368, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3939)(320 images: 4.290509 sec
# Train Epoch: 3, Loss: 0.337392, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3949)(320 images: 4.292775 sec
# Train Epoch: 3, Loss: 0.327753, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3959)(320 images: 4.306876 sec
# Train Epoch: 3, Loss: 0.271117, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3969)(320 images: 4.264823 sec
# Train Epoch: 3, Loss: 0.329842, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3979)(320 images: 4.300887 sec
# Train Epoch: 3, Loss: 0.285352, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3989)(320 images: 4.150403 sec
# Train Epoch: 3, Loss: 0.311747, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 3999)(320 images: 4.228225 sec
# Train Epoch: 3, Loss: 0.292609, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4009)(320 images: 4.243456 sec
# Train Epoch: 3, Loss: 0.364054, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4019)(320 images: 4.219960 sec
# Train Epoch: 3, Loss: 0.270873, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4029)(320 images: 4.135719 sec
# Train Epoch: 3, Loss: 0.289826, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4039)(320 images: 4.228168 sec
# Train Epoch: 3, Loss: 0.314634, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4049)(320 images: 4.101377 sec
# Train Epoch: 3, Loss: 0.378395, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4059)(320 images: 4.212335 sec
# Train Epoch: 3, Loss: 0.285764, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4069)(320 images: 4.104426 sec
# Train Epoch: 3, Loss: 0.389967, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4079)(320 images: 4.168249 sec
# Train Epoch: 3, Loss: 0.337163, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4089)(320 images: 4.224862 sec
# Train Epoch: 3, Loss: 0.366380, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4099)(320 images: 4.183118 sec
# Train Epoch: 3, Loss: 0.366264, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4109)(320 images: 4.248791 sec
# Train Epoch: 3, Loss: 0.330538, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4119)(320 images: 4.210230 sec
# Train Epoch: 3, Loss: 0.282104, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4129)(320 images: 4.335214 sec
# Train Epoch: 3, Loss: 0.311613, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4139)(320 images: 4.539826 sec
# Train Epoch: 3, Loss: 0.344731, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4149)(320 images: 4.595200 sec
# Train Epoch: 3, Loss: 0.313664, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4159)(320 images: 4.373380 sec
# Train Epoch: 3, Loss: 0.319193, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4169)(320 images: 4.799032 sec
# Train Epoch: 3, Loss: 0.293046, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4179)(320 images: 4.952662 sec
# Train Epoch: 3, Loss: 0.330272, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4189)(320 images: 4.588030 sec
# Train Epoch: 3, Loss: 0.300423, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4199)(320 images: 4.625921 sec
# Train Epoch: 3, Loss: 0.311302, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4209)(320 images: 4.378390 sec
# Train Epoch: 3, Loss: 0.335422, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4219)(320 images: 4.320701 sec
# Train Epoch: 3, Loss: 0.277939, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4229)(320 images: 4.321331 sec
# Train Epoch: 3, Loss: 0.298033, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4239)(320 images: 4.351566 sec
# Train Epoch: 3, Loss: 0.318602, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4249)(320 images: 4.412587 sec
# Train Epoch: 3, Loss: 0.314027, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4259)(320 images: 4.443890 sec
# Train Epoch: 3, Loss: 0.335367, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4269)(320 images: 4.169481 sec
# Train Epoch: 3, Loss: 0.337835, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4279)(320 images: 4.267129 sec
# Train Epoch: 3, Loss: 0.361683, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4289)(320 images: 4.361037 sec
# Train Epoch: 3, Loss: 0.294306, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4299)(320 images: 4.262991 sec
# Train Epoch: 3, Loss: 0.311460, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4309)(320 images: 4.265148 sec
# Train Epoch: 3, Loss: 0.343550, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4319)(320 images: 4.291094 sec
# Train Epoch: 3, Loss: 0.266595, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4329)(320 images: 4.326753 sec
# Train Epoch: 3, Loss: 0.392961, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4339)(320 images: 4.353941 sec
# Train Epoch: 3, Loss: 0.270969, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4349)(320 images: 4.343355 sec
# Train Epoch: 3, Loss: 0.320970, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4359)(320 images: 4.299665 sec
# Train Epoch: 3, Loss: 0.391309, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4369)(320 images: 4.415033 sec
# Train Epoch: 3, Loss: 0.350623, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4379)(320 images: 4.346368 sec
# Train Epoch: 3, Loss: 0.275375, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4389)(320 images: 4.226071 sec
# Train Epoch: 3, Loss: 0.361441, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4399)(320 images: 4.263761 sec
# Train Epoch: 3, Loss: 0.342945, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4409)(320 images: 4.306702 sec
# Train Epoch: 3, Loss: 0.276632, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4419)(320 images: 4.168286 sec
# Train Epoch: 3, Loss: 0.380584, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4429)(320 images: 4.220121 sec
# Train Epoch: 3, Loss: 0.321052, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4439)(320 images: 4.374913 sec
# Train Epoch: 3, Loss: 0.390331, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4449)(320 images: 4.363283 sec
# Train Epoch: 3, Loss: 0.370253, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4459)(320 images: 4.368166 sec
# Train Epoch: 3, Loss: 0.371923, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4469)(320 images: 4.137498 sec
# Train Epoch: 3, Loss: 0.402224, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4479)(320 images: 4.176350 sec
# Train Epoch: 3, Loss: 0.365899, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4489)(320 images: 4.168240 sec
# Train Epoch: 3, Loss: 0.340128, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4499)(320 images: 4.232993 sec
# Train Epoch: 3, Loss: 0.416646, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4509)(320 images: 4.125514 sec
# Train Epoch: 3, Loss: 0.318562, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4519)(320 images: 4.188947 sec
# Train Epoch: 3, Loss: 0.331695, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4529)(320 images: 4.248752 sec
# Train Epoch: 3, Loss: 0.314231, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4539)(320 images: 4.241759 sec
# Train Epoch: 3, Loss: 0.330403, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4549)(320 images: 4.198088 sec
# Train Epoch: 3, Loss: 0.331692, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4559)(320 images: 4.253974 sec
# Train Epoch: 3, Loss: 0.307450, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4569)(320 images: 4.232930 sec
# Train Epoch: 3, Loss: 0.341532, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4579)(320 images: 4.228045 sec
# Train Epoch: 3, Loss: 0.343498, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4589)(320 images: 4.302901 sec
# Train Epoch: 3, Loss: 0.255224, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4599)(320 images: 4.204676 sec
# Train Epoch: 3, Loss: 0.325718, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4609)(320 images: 4.232642 sec
# Train Epoch: 3, Loss: 0.362164, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4619)(320 images: 4.126284 sec
# Train Epoch: 3, Loss: 0.333691, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4629)(320 images: 4.128865 sec
# Train Epoch: 3, Loss: 0.364694, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4639)(320 images: 4.198548 sec
# Train Epoch: 3, Loss: 0.351523, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4649)(320 images: 4.286529 sec
# Train Epoch: 3, Loss: 0.323154, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4659)(320 images: 4.210182 sec
# Train Epoch: 3, Loss: 0.317636, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4669)(320 images: 3.964847 sec
# Train Epoch: 3, Loss: 0.304315, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4679)(320 images: 4.120880 sec
# Train Epoch: 3, Loss: 0.328888, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4689)(320 images: 4.228816 sec
# Train Epoch: 3, Loss: 0.333617, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4699)(320 images: 4.033167 sec
# Train Epoch: 3, Loss: 0.333084, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4709)(320 images: 3.970126 sec
# Train Epoch: 3, Loss: 0.303875, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4719)(320 images: 4.054573 sec
# Train Epoch: 3, Loss: 0.263408, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4729)(320 images: 4.115654 sec
# Train Epoch: 3, Loss: 0.304595, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4739)(320 images: 4.281879 sec
# Train Epoch: 3, Loss: 0.386135, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4749)(320 images: 4.223190 sec
# Train Epoch: 3, Loss: 0.304093, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4759)(320 images: 4.155413 sec
# Train Epoch: 3, Loss: 0.319709, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4769)(320 images: 4.211168 sec
# Train Epoch: 3, Loss: 0.302023, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4779)(320 images: 4.242720 sec
# Train Epoch: 3, Loss: 0.302386, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4789)(320 images: 4.198024 sec
# Train Epoch: 3, Loss: 0.298540, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4799)(320 images: 4.264001 sec
# Train Epoch: 3, Loss: 0.261856, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4809)(320 images: 4.157439 sec
# Train Epoch: 3, Loss: 0.291982, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4819)(320 images: 4.146231 sec
# Train Epoch: 3, Loss: 0.306262, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4829)(320 images: 4.119181 sec
# Train Epoch: 3, Loss: 0.294864, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4839)(320 images: 4.136834 sec
# Train Epoch: 3, Loss: 0.358602, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4849)(320 images: 4.174508 sec
# Train Epoch: 3, Loss: 0.327274, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4859)(320 images: 4.140188 sec
# Train Epoch: 3, Loss: 0.319810, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4869)(320 images: 4.777163 sec
# Train Epoch: 3, Loss: 0.317974, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4879)(320 images: 5.126264 sec
# Train Epoch: 3, Loss: 0.327876, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4889)(320 images: 4.934275 sec
# Train Epoch: 3, Loss: 0.411238, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4899)(320 images: 4.487880 sec
# Train Epoch: 3, Loss: 0.298826, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4909)(320 images: 4.408508 sec
# Train Epoch: 3, Loss: 0.299545, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4919)(320 images: 6.006516 sec
# Train Epoch: 3, Loss: 0.293136, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4929)(320 images: 5.891792 sec
# Train Epoch: 3, Loss: 0.315291, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4939)(320 images: 4.199413 sec
# Train Epoch: 3, Loss: 0.367795, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4949)(320 images: 4.385480 sec
# Train Epoch: 3, Loss: 0.387017, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4959)(320 images: 4.481919 sec
# Train Epoch: 3, Loss: 0.336568, Learning rate: 0.0024383748955776477
# Spended time for 10 batches (total: 4969)(320 images: 4.627527 sec
# ================================================================================
# Epoch 3, train loss: 0.321637, valid loss: 0.345561, valid metric: 0.923617
# ================================================================================
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:133: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
model_wrapper.save('/Users/igorfrolkin/Downloads/vad_model2_2.pth')

# %%
result_train_15_epoch = result_train.copy()

# %%
plt.plot(result_train_10_epoch['epoch_train_losses'] + result_train_12_epoch['epoch_train_losses'] + result_train['epoch_train_losses'])
plt.plot(result_train_10_epoch['epoch_valid_losses'] + result_train_12_epoch['epoch_valid_losses'] + result_train['epoch_valid_losses'])

# %%
plt.plot(result_train_10_epoch['epoch_valid_metrics'] + result_train_12_epoch['epoch_valid_metrics'] + result_train['epoch_valid_metrics'])

# %%
y_true, y_proba = test_result(model, test_data_loader)
# Out:
# {'test_loss': 0.34231153279758414, 'test_metric': 0.9246416615463038}
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plot_PR_ROC(y_true, y_proba)

# %%
show_proba_calibration_plots(y_proba, y_true)

# %%
report(y_true, y_proba, 0.42)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85     20455
#            1       0.91      0.82      0.86     23779
#
#     accuracy                           0.86     44234
#    macro avg       0.86      0.86      0.86     44234
# weighted avg       0.86      0.86      0.86     44234
#
# ---------------
# Матрица ошибок:
# [[18466  1989]
#  [ 4341 19438]]
# ---------------
# Правильно предсказано 0: 18466
# Правильно предсказано 1: 19438
# Ложноотрицательных (FN, ош2р, пропуск события): 4341
# Ложноположительных (FP, ош1р, ложная  тревога): 1989
# Всего ошибок: 6330
